# %% [markdown]
# # Apply Encoder of Transformer Model (Self Attention) to Explore RNA-Protein Binding

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, Normalizer, KBinsDiscretizer
from sklearn.pipeline import Pipeline, make_pipeline
import datetime

# %% [markdown]
# ## Data preparation

# %%
df_preprocess = pd.read_csv("Result_Structure.csv")
df = df_preprocess[df_preprocess["Qc"]!=1]
df.head()
# Out:
#                       Sequence                    Structure   MFE         K  \
# 0  GGAUCCAUUCAAAAAAAGAACGGAUCC  ((((((.(((.......))).)))))) -10.5  4.971544
# 1  GGAUCCAUUCAAAAAACGAACGGAUCC  ((((((.(((.......))).)))))) -10.5  4.514383
# 2  GGAUCCAUUCAAAAAAGGAACGGAUCC  ((((((.(((.......))).)))))) -10.4  3.609146
# 3  GGAUCCAUUCAAAAAAUGAACGGAUCC  ((((((.((((.....)))).)))))) -11.7  6.607685
# 4  GGAUCCAUUCAAAAACAGAACGGAUCC  ((((((.(((.......))).)))))) -10.5  3.221327
#
#          KA       RKA  Qc sevenMer
# 0  0.201145  0.395847   0  AAAAAAA
# 1  0.221514  0.435934   0  AAAAAAC
# 2  0.277074  0.545273   0  AAAAAAG
# 3  0.151339  0.297831   0  AAAAAAU
# 4  0.310431  0.610919   0  AAAAACA

# %% [markdown]
# ## Set hyper parameters

# %%
seq_length=7
num_layers=1
d_model=21
num_heads=3
dff=64

# %% [markdown]
# ## Functions to handle the RNA Inputs

# %%
def cutWord(x, window=1, length = seq_length):
    seq2word = []
    for i in range(length):
        seq2word.append(x[i*window:i*window+window])
    return " ".join(seq2word)

def RKA_bin(x):
    if x >= 0.8:
        return(1)
    else:
        return(0)

def MFE_bin(x):
    if x >= -14.:
        return(1)
    else:
        return(0)

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
print(scaler.fit(df[["RKA"]]))

df["RKA_norm"] = scaler.transform(df[["RKA"]])
df[["RKA_logplus1"]] = df[["RKA"]].apply(lambda x: np.log(1+x))
# Out:
# MinMaxScaler()
# /var/folders/x_/gdpx2y_53xb045v6zhcn7rrr0000gn/T/ipykernel_82828/377741743.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["RKA_norm"] = scaler.transform(df[["RKA"]])
# /var/folders/x_/gdpx2y_53xb045v6zhcn7rrr0000gn/T/ipykernel_82828/377741743.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["RKA_logplus1"]] = df[["RKA"]].apply(lambda x: np.log(1+x))

# %%
sns.histplot(df[["RKA_logplus1"]])
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Create dataset for Tensorflow model

# %%
df["RKA_level"] = df.RKA.apply(RKA_bin)
df["MFE_level"] = df.RKA.apply(RKA_bin)
target = df[["MFE_level","RKA_level"]].copy()
sequences = df[["sevenMer"]].copy()
seq_spaced = sequences.applymap(cutWord)

vectorize_layer = tf.keras.layers.TextVectorization(max_tokens=d_model, standardize='lower_and_strip_punctuation', split='whitespace', ngrams=None, output_mode='int')
vectorize_layer.adapt(seq_spaced)

#Divide to train and test
X_train, X_test, y_train, y_test = train_test_split(seq_spaced, df["RKA_logplus1"], test_size=0.33, random_state=42)
#vec_seq = vectorize_layer(X_train)
#seq_database = v
all_vec_seq = vectorize_layer(seq_spaced)
all_vec_seq = tf.data.Dataset.from_tensor_slices(all_vec_seq)
#target_database = tf.data.Dataset.from_tensor_slices(y_train)
target_database = tf.data.Dataset.from_tensor_slices(df["RKA_logplus1"])
x_test_database = vectorize_layer(X_test)
x_test_database = tf.data.Dataset.from_tensor_slices(x_test_database)
y_test_database = tf.data.Dataset.from_tensor_slices(y_test)
# Out:
# /var/folders/x_/gdpx2y_53xb045v6zhcn7rrr0000gn/T/ipykernel_82828/2643770854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["RKA_level"] = df.RKA.apply(RKA_bin)
# /var/folders/x_/gdpx2y_53xb045v6zhcn7rrr0000gn/T/ipykernel_82828/2643770854.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MFE_level"] = df.RKA.apply(RKA_bin)
# 2022-03-19 19:47:15.233222: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-19 19:47:15.233742: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-03-19 19:47:15.234002: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-03-19 19:47:15.361737: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Metal device set to: AMD Radeon Pro 560X
#
# systemMemory: 16.00 GB
# maxCacheSize: 2.00 GB

# %%
#train_set = tf.data.Dataset.zip((seq_database, target_database))
train_set = tf.data.Dataset.zip((all_vec_seq, target_database))
test_dataset = tf.data.Dataset.zip((x_test_database, y_test_database))
real_train_set = train_set.batch(50).shuffle(50)
test_dataset = test_dataset.batch(50)
#next(iter(train_set.batch(10)))

# %% [markdown]
# ## Build Encoder of Transformer model
#
# ### Self attention

# %%
def scaled_dot_product_attention(q, k, v, mask=None):
    matmul_qk = tf.matmul(q, k, transpose_b=True) # Shape = (..., seq_len_q, seq_len_k)
    # scale matmul_qk
    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    # add the mask to the scaled tensor.
    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

    # softmax is normalized on the last axis (seq_len_k) so that the scores
    # add up to 1.
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

    # calculate matmul_qk_v
    output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

    return output, attention_weights, matmul_qk

#create multi-head attention layer
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        #Because for multi-head, head number * depth = multi-head
        assert d_model % self.num_heads == 0
        self.depth = d_model // self.num_heads

        #Set layers for q, k, v
        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)
    
    def split_heads(self, x, batch_size):
        """Split the last dimension into (num_heads, depth).
        Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
        """
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth)) 
        return tf.transpose(x, perm=[0, 2, 1, 3]) # shape = (batch_size, num_heads, seq_len, depth)

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]
        q = self.wq(q)  # (batch_size, seq_len, d_model)
        k = self.wk(k)  # (batch_size, seq_len, d_model)
        v = self.wv(v)  # (batch_size, seq_len, d_model)

        q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
        k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
        v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

        # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
        # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
        scaled_attention, attention_weights, matmul_qk= scaled_dot_product_attention(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

        concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)
        output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

        return output, attention_weights, matmul_qk

# %% [markdown]
# ### Fully connected layer and Encoder layer

# %%
def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
        tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
        ])
        
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        #define layers
        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask=None):

        attn_output, attn_weight, matmul_qk = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

        ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

        return out2, attn_weight, matmul_qk

# %% [markdown]
# ### Position Encoding

# %%
def get_angles(pos, i, d_model):
    angle_rate = 1/np.power(10000, (2*(i/2))/np.float32(d_model))
    return pos*angle_rate

def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                            np.arange(d_model)[np.newaxis, :]
                            ,d_model)
    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    pos_encoding = angle_rads[np.newaxis, ...]
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
positional_encoding(1, 9)
# Out:
# <tf.Tensor: shape=(1, 1, 9), dtype=float32, numpy=array([[[0., 1., 0., 1., 0., 1., 0., 1., 0.]]], dtype=float32)>

# %% [markdown]
# ### Encoder

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
                 maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()
        self.d_model = d_model
        self.num_layers = num_layers #how many encoder layers
        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)
        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)
        self.attention_weights = {}
        self.matmul_qks = {}
        
    def call(self, x, training, mask=None):
        #attention_weights = {}
        #encoding and position encoding
        seq_len = tf.shape(x)[1]
        x = self.embedding(x) # (batch_size, input_seq_len, d_model)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        
        
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block, matmul_qk = self.enc_layers[i](x, training, mask)
            self.attention_weights[f'attentions_{i+1}'] = block
            self.matmul_qks[f'matmul_qk_{i+1}'] = matmul_qk
            
        #attention_weights[f'decoder_layer{i+1}_block'] = block
        return x, block # (batch_size, input_seq_len, d_model)
    
    def get_attention(self):
        return self.attention_weights
    def get_matmul_qks(self):
        return self.matmul_qks

# %% [markdown]
# ### Test of Encoder

# %%
sample_encoder = Encoder(num_layers=2, d_model=5, num_heads=1,
                         dff=dff, input_vocab_size=10,
                         maximum_position_encoding=24)
                         
temp_input = tf.random.uniform((3, 24), dtype=tf.int64, minval=0, maxval=200)

sample_encoder_output = sample_encoder(temp_input, training=False, mask=None)

sample_encoder_output[0].shape
# Out:
# TensorShape([3, 24, 5])

# %% [markdown]
# ## Create model

# %%
def create_model(seq_length, num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding, rate=0.1):
    input = tf.keras.Input(shape=(seq_length,))
    x , aws= Encoder(num_layers, d_model, num_heads, dff,
                input_vocab_size, maximum_position_encoding, rate=0.1)(input)
    x = tf.keras.layers.Reshape((seq_length*d_model,))(x)
    x = tf.keras.layers.Dense(seq_length, activation='relu')(x)
    x = tf.keras.layers.Dense(1)(x)
    output = tf.squeeze(x)
    
    return tf.keras.Model(inputs=input, outputs=output)

# %%
model = create_model(seq_length=seq_length, num_layers= num_layers, d_model=d_model, num_heads=num_heads,
                         dff=dff, input_vocab_size=10,
                         maximum_position_encoding=7)
p = vectorize_layer(seq_spaced.iloc[17])
model(p)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2.8596268>

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 7)]               0
#
#  encoder_1 (Encoder)         ((None, 7, 21),           4915
#                               (None, 3, None, None))
#
#  reshape (Reshape)           (None, 147)               0
#
#  dense_18 (Dense)            (None, 7)                 1036
#
#  dense_19 (Dense)            (None, 1)                 8
#
#  tf.compat.v1.squeeze (TFOpL  None                     0
#  ambda)
#
# =================================================================
# Total params: 5,959
# Trainable params: 5,959
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Test our model to see if it can work and get the attention matrix

# %%
for i in real_train_set.take(1):
    q = model(i[0])
att = model.layers[1].get_attention()['attentions_1']
qk = model.layers[1].get_matmul_qks()['matmul_qk_1']
#forheat = tf.squeeze(att).numpy()
sns.heatmap(qk[(0,0)])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Custom Schedule/ Accuracy/ Loss functions

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()
        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)
        self.warmup_steps = warmup_steps
    
    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)
        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                     epsilon=1e-9)
#optimizer = tf.keras.optimizers.Adam()

#loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False, reduction='none')
loss_object = loss=tf.keras.losses.MeanAbsoluteError()

def loss_function(real, pred):
    #mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    #mask = tf.cast(mask, dtype=loss_.dtype)
    #loss_ *= mask
    #return tf.reduce_sum(loss_)/tf.reduce_sum(mask)
    return tf.reduce_sum(loss_)


def accuracy_function(real, pred):
    accuracies = loss_object(real, pred)
    #accuracies = tf.equal(real, tf.argmax(pred, axis=2))
    #accuracies = tf.keras.losses.MeanAbsoluteError(real, pred)
    #mask = tf.math.logical_not(tf.math.equal(real, 0))
    #accuracies = tf.math.logical_and(mask, accuracies)
    #accuracies = tf.cast(accuracies, dtype=tf.float32)
    #mask = tf.cast(mask, dtype=tf.float32)
    #return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)
    return tf.reduce_sum(accuracies)

train_metric = tfa.metrics.r_square.RSquare()
test_metric = tfa.metrics.r_square.RSquare()

train_loss = tf.keras.metrics.Mean(name='train_loss')
test_loss = tf.keras.metrics.Mean(name='test_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')
test_accuracy = tf.keras.metrics.Mean(name='test_accuracy')

# %%
checkpoint_path = "./checkpoints_64_21_pos/train"

ckpt = tf.train.Checkpoint(transformer=model,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print('Latest checkpoint restored!!')

# %% [markdown]
# ## Customized Train/Test steps

# %%
# The @tf.function trace-compiles train_step into a TF graph for faster
# execution. The function specializes to the precise shape of the argument
# tensors. To avoid re-tracing due to the variable sequence lengths or variable
# batch sizes (the last batch is smaller), use input_signature to specify
# more generic shapes.

#train_step_signature = [
#    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
#    tf.TensorSpec(shape=(None), dtype=tf.int64),
#]


#@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
    #inp = inp
    target = tar

    with tf.GradientTape() as tape:
        predictions = model(inp, training = True)
        loss = loss_function(target, predictions)

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
    train_loss(loss)

    train_metric.update_state(target, predictions)
    #result = metric.result()
    #train_accuracy(result)
    #train_accuracy(accuracy_function(target, predictions))
    
def test_step(model, inp, tar):
    #inp = inp
    target = tar
    predictions = model(inp)
    testloss = loss_function(tar, predictions)
    test_loss(testloss)
    test_metric.update_state(target, predictions)

    #result = metric.result()
    #test_accuracy(result)

    #train_accuracy(accuracy_function(target, predictions))

current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = 'logs/gradient_tape/' + current_time + '/train'
test_log_dir = 'logs/gradient_tape/' + current_time + '/test'
train_summary_writer = tf.summary.create_file_writer(train_log_dir)
test_summary_writer = tf.summary.create_file_writer(test_log_dir)

# %% [markdown]
# ## Train loop

# %%
import time
EPOCHS=300
for epoch in range(EPOCHS):
  start = time.time()

  train_loss.reset_states()
  train_accuracy.reset_states()


  for (batch, (inp, tar)) in enumerate(real_train_set):
    train_step(inp, tar)
    if batch % 300 == 0:
      print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_metric.result():.4f}')

  with train_summary_writer.as_default():
    tf.summary.scalar('loss', train_loss.result(), step=epoch)
    tf.summary.scalar('accuracy', train_metric.result(), step=epoch)

  for (batch, (inp, tar)) in enumerate(test_dataset):
    test_step(model, inp, tar)

  with test_summary_writer.as_default():
    #tf.summary.scalar('loss', test_loss.result(), step=epoch)
    tf.summary.scalar('accuracy', test_metric.result(), step=epoch)

  template = 'Epoch {}, Loss: {}, Test Loss: {}, Test R^2: {}'
  print (template.format(epoch+1,
                         train_loss.result(),
                         test_loss.result(),
                         test_metric.result()
                         ))
  #Print out information
 

  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')
    print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_metric.result():.4f}')
    print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 2.2194 Accuracy -337.0789
# Epoch 1 Batch 300 Loss 0.6944 Accuracy -56.5982
# Epoch 1, Loss: 0.6798944473266602, Test Loss: 0.31030556559562683, Test R^2: -5.170299530029297
# Epoch 2 Batch 0 Loss 0.2070 Accuracy -53.7268
# Epoch 2 Batch 300 Loss 0.1322 Accuracy -27.5712
# Epoch 2, Loss: 0.1314821094274521, Test Loss: 0.24271763861179352, Test R^2: -3.33779239654541
# Epoch 3 Batch 0 Loss 0.0993 Accuracy -27.1980
# Epoch 3 Batch 300 Loss 0.1106 Accuracy -18.3421
# Epoch 3, Loss: 0.11013314127922058, Test Loss: 0.19689366221427917, Test R^2: -2.231171131134033
# Epoch 4 Batch 0 Loss 0.1120 Accuracy -18.1768
# Epoch 4 Batch 300 Loss 0.1034 Accuracy -13.7251
# Epoch 4, Loss: 0.10295096784830093, Test Loss: 0.17362090945243835, Test R^2: -1.6779379844665527
# Epoch 5 Batch 0 Loss 0.0955 Accuracy -13.6348
# Epoch 5 Batch 300 Loss 0.1002 Accuracy -10.9657
# Epoch 5, Loss: 0.09989988058805466, Test Loss: 0.15957196056842804, Test R^2: -1.3415257930755615
# Saving checkpoint for epoch 5 at ./checkpoints_64_21_pos/train/ckpt-1
# Epoch 5 Loss 0.0999 Accuracy -10.8999
# Time taken for 1 epoch: 45.69 secs
#
# Epoch 6 Batch 0 Loss 0.1256 Accuracy -10.8916
# Epoch 6 Batch 300 Loss 0.0974 Accuracy -9.1098
# Epoch 6, Loss: 0.0973985493183136, Test Loss: 0.15027692914009094, Test R^2: -1.1182317733764648
# Epoch 7 Batch 0 Loss 0.1714 Accuracy -9.0552
# Epoch 7 Batch 300 Loss 0.0961 Accuracy -7.7740
# Epoch 7, Loss: 0.09553329646587372, Test Loss: 0.14271755516529083, Test R^2: -0.9372988939285278
# Epoch 8 Batch 0 Loss 0.0780 Accuracy -7.7473
# Epoch 8 Batch 300 Loss 0.0947 Accuracy -6.7809
# Epoch 8, Loss: 0.09458998590707779, Test Loss: 0.13771642744541168, Test R^2: -0.8043981790542603
# Epoch 9 Batch 0 Loss 0.0818 Accuracy -6.7590
# Epoch 9 Batch 300 Loss 0.0912 Accuracy -6.0015
# Epoch 9, Loss: 0.09068820625543594, Test Loss: 0.1325962096452713, Test R^2: -0.6890784502029419
# Epoch 10 Batch 0 Loss 0.1115 Accuracy -5.9811
# Epoch 10 Batch 300 Loss 0.0889 Accuracy -5.3695
# Epoch 10, Loss: 0.08832240104675293, Test Loss: 0.1284661889076233, Test R^2: -0.5995829105377197
# Saving checkpoint for epoch 10 at ./checkpoints_64_21_pos/train/ckpt-2
# Epoch 10 Loss 0.0883 Accuracy -5.3584
# Time taken for 1 epoch: 37.85 secs
#
# Epoch 11 Batch 0 Loss 0.1037 Accuracy -5.3564
# Epoch 11 Batch 300 Loss 0.0848 Accuracy -4.8575
# Epoch 11, Loss: 0.08514408767223358, Test Loss: 0.1247117668390274, Test R^2: -0.515852689743042
# Epoch 12 Batch 0 Loss 0.0692 Accuracy -4.8415
# Epoch 12 Batch 300 Loss 0.0838 Accuracy -4.4209
# Epoch 12, Loss: 0.08370931446552277, Test Loss: 0.12151797860860825, Test R^2: -0.44542956352233887
# Epoch 13 Batch 0 Loss 0.1441 Accuracy -4.4095
# Epoch 13 Batch 300 Loss 0.0835 Accuracy -4.0561
# Epoch 13, Loss: 0.08364158868789673, Test Loss: 0.11897367984056473, Test R^2: -0.39283668994903564
# Epoch 14 Batch 0 Loss 0.1041 Accuracy -4.0457
# Epoch 14 Batch 300 Loss 0.0814 Accuracy -3.7409
# Epoch 14, Loss: 0.08149676769971848, Test Loss: 0.11606180667877197, Test R^2: -0.3343852758407593
# Epoch 15 Batch 0 Loss 0.0662 Accuracy -3.7319
# Epoch 15 Batch 300 Loss 0.0803 Accuracy -3.4638
# Epoch 15, Loss: 0.0798645094037056, Test Loss: 0.11369266360998154, Test R^2: -0.2866034507751465
# Saving checkpoint for epoch 15 at ./checkpoints_64_21_pos/train/ckpt-3
# Epoch 15 Loss 0.0799 Accuracy -3.4581
# Time taken for 1 epoch: 41.04 secs
#
# Epoch 16 Batch 0 Loss 0.0641 Accuracy -3.4576
# Epoch 16 Batch 300 Loss 0.0768 Accuracy -3.2277
# Epoch 16, Loss: 0.07732877135276794, Test Loss: 0.11139959841966629, Test R^2: -0.2413179874420166
# Epoch 17 Batch 0 Loss 0.0852 Accuracy -3.2150
# Epoch 17 Batch 300 Loss 0.0759 Accuracy -3.0044
# Epoch 17, Loss: 0.0756576657295227, Test Loss: 0.10937872529029846, Test R^2: -0.19988560676574707
# Epoch 18 Batch 0 Loss 0.1284 Accuracy -2.9996
# Epoch 18 Batch 300 Loss 0.0762 Accuracy -2.8137
# Epoch 18, Loss: 0.07574325054883957, Test Loss: 0.10751558840274811, Test R^2: -0.16362619400024414
# Epoch 19 Batch 0 Loss 0.0876 Accuracy -2.8087
# Epoch 19 Batch 300 Loss 0.0751 Accuracy -2.6427
# Epoch 19, Loss: 0.07531711459159851, Test Loss: 0.10582488030195236, Test R^2: -0.13182544708251953
# Epoch 20 Batch 0 Loss 0.0445 Accuracy -2.6380
# Epoch 20 Batch 300 Loss 0.0732 Accuracy -2.4863
# Epoch 20, Loss: 0.0731031745672226, Test Loss: 0.10440506786108017, Test R^2: -0.10477113723754883
# Saving checkpoint for epoch 20 at ./checkpoints_64_21_pos/train/ckpt-4
# Epoch 20 Loss 0.0731 Accuracy -2.4828
# Time taken for 1 epoch: 44.38 secs
#
# Epoch 21 Batch 0 Loss 0.1140 Accuracy -2.4820
# Epoch 21 Batch 300 Loss 0.0721 Accuracy -2.3444
# Epoch 21, Loss: 0.07206807285547256, Test Loss: 0.10283707827329636, Test R^2: -0.0751122236251831
# Epoch 22 Batch 0 Loss 0.0967 Accuracy -2.3407
# Epoch 22 Batch 300 Loss 0.0714 Accuracy -2.2154
# Epoch 22, Loss: 0.07137571275234222, Test Loss: 0.10136842727661133, Test R^2: -0.04843580722808838
# Epoch 23 Batch 0 Loss 0.0916 Accuracy -2.2116
# Epoch 23 Batch 300 Loss 0.0715 Accuracy -2.0967
# Epoch 23, Loss: 0.07132185250520706, Test Loss: 0.09998825937509537, Test R^2: -0.023172855377197266
# Epoch 24 Batch 0 Loss 0.0848 Accuracy -2.0939
# Epoch 24 Batch 300 Loss 0.0705 Accuracy -1.9887
# Epoch 24, Loss: 0.07076682895421982, Test Loss: 0.09882703423500061, Test R^2: -0.0004904270172119141
# Epoch 25 Batch 0 Loss 0.0611 Accuracy -1.9856
# Epoch 25 Batch 300 Loss 0.0693 Accuracy -1.8879
# Epoch 25, Loss: 0.06928529590368271, Test Loss: 0.09770616888999939, Test R^2: 0.02095353603363037
# Saving checkpoint for epoch 25 at ./checkpoints_64_21_pos/train/ckpt-5
# Epoch 25 Loss 0.0693 Accuracy -1.8855
# Time taken for 1 epoch: 44.39 secs
#
# Epoch 26 Batch 0 Loss 0.0486 Accuracy -1.8853
# Epoch 26 Batch 300 Loss 0.0683 Accuracy -1.7944
# Epoch 26, Loss: 0.06817217916250229, Test Loss: 0.09661801904439926, Test R^2: 0.04175466299057007
# Epoch 27 Batch 0 Loss 0.0497 Accuracy -1.7921
# Epoch 27 Batch 300 Loss 0.0675 Accuracy -1.7084
# Epoch 27, Loss: 0.06803524494171143, Test Loss: 0.09572535753250122, Test R^2: 0.06029754877090454
# Epoch 28 Batch 0 Loss 0.0496 Accuracy -1.7057
# Epoch 28 Batch 300 Loss 0.0677 Accuracy -1.6271
# Epoch 28, Loss: 0.06787768751382828, Test Loss: 0.09481533616781235, Test R^2: 0.07754945755004883
# Epoch 29 Batch 0 Loss 0.0864 Accuracy -1.6249
# Epoch 29 Batch 300 Loss 0.0672 Accuracy -1.5521
# Epoch 29, Loss: 0.06737437844276428, Test Loss: 0.09394145011901855, Test R^2: 0.09444719552993774
# Epoch 30 Batch 0 Loss 0.0515 Accuracy -1.5502
# Epoch 30 Batch 300 Loss 0.0663 Accuracy -1.4812
# Epoch 30, Loss: 0.06642809510231018, Test Loss: 0.09301691502332687, Test R^2: 0.11071550846099854
# Saving checkpoint for epoch 30 at ./checkpoints_64_21_pos/train/ckpt-6
# Epoch 30 Loss 0.0664 Accuracy -1.4800
# Time taken for 1 epoch: 41.78 secs
#
# Epoch 31 Batch 0 Loss 0.0422 Accuracy -1.4799
# Epoch 31 Batch 300 Loss 0.0663 Accuracy -1.4156
# Epoch 31, Loss: 0.06628543138504028, Test Loss: 0.09217920899391174, Test R^2: 0.12616217136383057
# Epoch 32 Batch 0 Loss 0.0618 Accuracy -1.4138
# Epoch 32 Batch 300 Loss 0.0659 Accuracy -1.3532
# Epoch 32, Loss: 0.06593234837055206, Test Loss: 0.09142383188009262, Test R^2: 0.1392917037010193
# Epoch 33 Batch 0 Loss 0.0519 Accuracy -1.3518
# Epoch 33 Batch 300 Loss 0.0657 Accuracy -1.2951
# Epoch 33, Loss: 0.0657561719417572, Test Loss: 0.09069685637950897, Test R^2: 0.15276449918746948
# Epoch 34 Batch 0 Loss 0.0546 Accuracy -1.2936
# Epoch 34 Batch 300 Loss 0.0651 Accuracy -1.2401
# Epoch 34, Loss: 0.06515343487262726, Test Loss: 0.08996762335300446, Test R^2: 0.16579151153564453
# Epoch 35 Batch 0 Loss 0.0467 Accuracy -1.2386
# Epoch 35 Batch 300 Loss 0.0648 Accuracy -1.1882
# Epoch 35, Loss: 0.06509779393672943, Test Loss: 0.08930134028196335, Test R^2: 0.17748558521270752
# Saving checkpoint for epoch 35 at ./checkpoints_64_21_pos/train/ckpt-7
# Epoch 35 Loss 0.0651 Accuracy -1.1869
# Time taken for 1 epoch: 46.17 secs
#
# Epoch 36 Batch 0 Loss 0.0813 Accuracy -1.1866
# Epoch 36 Batch 300 Loss 0.0647 Accuracy -1.1385
# Epoch 36, Loss: 0.06442104279994965, Test Loss: 0.0887124165892601, Test R^2: 0.18748682737350464
# Epoch 37 Batch 0 Loss 0.0589 Accuracy -1.1374
# Epoch 37 Batch 300 Loss 0.0640 Accuracy -1.0921
# Epoch 37, Loss: 0.06403695046901703, Test Loss: 0.08810550719499588, Test R^2: 0.19834208488464355
# Epoch 38 Batch 0 Loss 0.0472 Accuracy -1.0908
# Epoch 38 Batch 300 Loss 0.0646 Accuracy -1.0474
# Epoch 38, Loss: 0.06431113183498383, Test Loss: 0.08750481903553009, Test R^2: 0.2090243697166443
# Epoch 39 Batch 0 Loss 0.0467 Accuracy -1.0467
# Epoch 39 Batch 300 Loss 0.0641 Accuracy -1.0057
# Epoch 39, Loss: 0.06406436860561371, Test Loss: 0.08693002164363861, Test R^2: 0.21924203634262085
# Epoch 40 Batch 0 Loss 0.0711 Accuracy -1.0046
# Epoch 40 Batch 300 Loss 0.0636 Accuracy -0.9660
# Epoch 40, Loss: 0.06347963958978653, Test Loss: 0.08633092045783997, Test R^2: 0.22922217845916748
# Saving checkpoint for epoch 40 at ./checkpoints_64_21_pos/train/ckpt-8
# Epoch 40 Loss 0.0635 Accuracy -0.9647
# Time taken for 1 epoch: 46.87 secs
#
# Epoch 41 Batch 0 Loss 0.0456 Accuracy -0.9646
# Epoch 41 Batch 300 Loss 0.0636 Accuracy -0.9277
# Epoch 41, Loss: 0.06373586505651474, Test Loss: 0.08588553965091705, Test R^2: 0.238009512424469
# Epoch 42 Batch 0 Loss 0.0626 Accuracy -0.9266
# Epoch 42 Batch 300 Loss 0.0631 Accuracy -0.8913
# Epoch 42, Loss: 0.06295385211706161, Test Loss: 0.0853641927242279, Test R^2: 0.24717384576797485
# Epoch 43 Batch 0 Loss 0.0446 Accuracy -0.8902
# Epoch 43 Batch 300 Loss 0.0625 Accuracy -0.8562
# Epoch 43, Loss: 0.06238960847258568, Test Loss: 0.08485108613967896, Test R^2: 0.25572752952575684
# Epoch 44 Batch 0 Loss 0.0607 Accuracy -0.8553
# Epoch 44 Batch 300 Loss 0.0620 Accuracy -0.8228
# Epoch 44, Loss: 0.061968475580215454, Test Loss: 0.08436752110719681, Test R^2: 0.263877272605896
# Epoch 45 Batch 0 Loss 0.0774 Accuracy -0.8217
# Epoch 45 Batch 300 Loss 0.0620 Accuracy -0.7909
# Epoch 45, Loss: 0.061973027884960175, Test Loss: 0.08394460380077362, Test R^2: 0.2716410756111145
# Saving checkpoint for epoch 45 at ./checkpoints_64_21_pos/train/ckpt-9
# Epoch 45 Loss 0.0620 Accuracy -0.7900
# Time taken for 1 epoch: 48.78 secs
#
# Epoch 46 Batch 0 Loss 0.0673 Accuracy -0.7899
# Epoch 46 Batch 300 Loss 0.0615 Accuracy -0.7600
# Epoch 46, Loss: 0.06158844009041786, Test Loss: 0.08349082618951797, Test R^2: 0.2790326476097107
# Epoch 47 Batch 0 Loss 0.0586 Accuracy -0.7593
# Epoch 47 Batch 300 Loss 0.0613 Accuracy -0.7306
# Epoch 47, Loss: 0.06135343015193939, Test Loss: 0.08308794349431992, Test R^2: 0.2857774496078491
# Epoch 48 Batch 0 Loss 0.0438 Accuracy -0.7299
# Epoch 48 Batch 300 Loss 0.0622 Accuracy -0.7026
# Epoch 48, Loss: 0.06195537745952606, Test Loss: 0.08267224580049515, Test R^2: 0.29273808002471924
# Epoch 49 Batch 0 Loss 0.0424 Accuracy -0.7019
# Epoch 49 Batch 300 Loss 0.0612 Accuracy -0.6753
# Epoch 49, Loss: 0.061146367341279984, Test Loss: 0.08229368925094604, Test R^2: 0.2995535135269165
# Epoch 50 Batch 0 Loss 0.0396 Accuracy -0.6748
# Epoch 50 Batch 300 Loss 0.0611 Accuracy -0.6494
# Epoch 50, Loss: 0.06115294247865677, Test Loss: 0.08189676702022552, Test R^2: 0.30607277154922485
# Saving checkpoint for epoch 50 at ./checkpoints_64_21_pos/train/ckpt-10
# Epoch 50 Loss 0.0612 Accuracy -0.6488
# Time taken for 1 epoch: 48.68 secs
#
# Epoch 51 Batch 0 Loss 0.0490 Accuracy -0.6488
# Epoch 51 Batch 300 Loss 0.0606 Accuracy -0.6244
# Epoch 51, Loss: 0.06050446256995201, Test Loss: 0.08152454346418381, Test R^2: 0.312278151512146
# Epoch 52 Batch 0 Loss 0.0475 Accuracy -0.6237
# Epoch 52 Batch 300 Loss 0.0608 Accuracy -0.6002
# Epoch 52, Loss: 0.06056392192840576, Test Loss: 0.08116831630468369, Test R^2: 0.3181573748588562
# Epoch 53 Batch 0 Loss 0.0369 Accuracy -0.5996
# Epoch 53 Batch 300 Loss 0.0605 Accuracy -0.5770
# Epoch 53, Loss: 0.060546401888132095, Test Loss: 0.08081257343292236, Test R^2: 0.324021577835083
# Epoch 54 Batch 0 Loss 0.0463 Accuracy -0.5764
# Epoch 54 Batch 300 Loss 0.0603 Accuracy -0.5545
# Epoch 54, Loss: 0.06014852225780487, Test Loss: 0.08046440780162811, Test R^2: 0.32965177297592163
# Epoch 55 Batch 0 Loss 0.0527 Accuracy -0.5540
# Epoch 55 Batch 300 Loss 0.0596 Accuracy -0.5329
# Epoch 55, Loss: 0.05980467051267624, Test Loss: 0.08012568205595016, Test R^2: 0.3351835012435913
# Saving checkpoint for epoch 55 at ./checkpoints_64_21_pos/train/ckpt-11
# Epoch 55 Loss 0.0598 Accuracy -0.5323
# Time taken for 1 epoch: 48.74 secs
#
# Epoch 56 Batch 0 Loss 0.0740 Accuracy -0.5323
# Epoch 56 Batch 300 Loss 0.0597 Accuracy -0.5119
# Epoch 56, Loss: 0.05958938971161842, Test Loss: 0.07980965822935104, Test R^2: 0.3405146598815918
# Epoch 57 Batch 0 Loss 0.0638 Accuracy -0.5114
# Epoch 57 Batch 300 Loss 0.0595 Accuracy -0.4918
# Epoch 57, Loss: 0.059494152665138245, Test Loss: 0.07951260358095169, Test R^2: 0.3457571864128113
# Epoch 58 Batch 0 Loss 0.0550 Accuracy -0.4912
# Epoch 58 Batch 300 Loss 0.0594 Accuracy -0.4721
# Epoch 58, Loss: 0.05934789776802063, Test Loss: 0.07921002060174942, Test R^2: 0.35086172819137573
# Epoch 59 Batch 0 Loss 0.0547 Accuracy -0.4717
# Epoch 59 Batch 300 Loss 0.0590 Accuracy -0.4532
# Epoch 59, Loss: 0.058925189077854156, Test Loss: 0.07892107218503952, Test R^2: 0.35562360286712646
# Epoch 60 Batch 0 Loss 0.0618 Accuracy -0.4527
# Epoch 60 Batch 300 Loss 0.0593 Accuracy -0.4349
# Epoch 60, Loss: 0.05919946730136871, Test Loss: 0.07862762361764908, Test R^2: 0.36049145460128784
# Saving checkpoint for epoch 60 at ./checkpoints_64_21_pos/train/ckpt-12
# Epoch 60 Loss 0.0592 Accuracy -0.4345
# Time taken for 1 epoch: 48.51 secs
#
# Epoch 61 Batch 0 Loss 0.0515 Accuracy -0.4344
# Epoch 61 Batch 300 Loss 0.0585 Accuracy -0.4170
# Epoch 61, Loss: 0.05845015123486519, Test Loss: 0.07835159450769424, Test R^2: 0.36502331495285034
# Epoch 62 Batch 0 Loss 0.0520 Accuracy -0.4166
# Epoch 62 Batch 300 Loss 0.0589 Accuracy -0.4001
# Epoch 62, Loss: 0.05912928283214569, Test Loss: 0.0780925527215004, Test R^2: 0.36946094036102295
# Epoch 63 Batch 0 Loss 0.0562 Accuracy -0.3996
# Epoch 63 Batch 300 Loss 0.0585 Accuracy -0.3834
# Epoch 63, Loss: 0.05848975107073784, Test Loss: 0.07785529643297195, Test R^2: 0.3733537793159485
# Epoch 64 Batch 0 Loss 0.0678 Accuracy -0.3829
# Epoch 64 Batch 300 Loss 0.0587 Accuracy -0.3672
# Epoch 64, Loss: 0.05863340198993683, Test Loss: 0.07759696245193481, Test R^2: 0.3776702284812927
# Epoch 65 Batch 0 Loss 0.0585 Accuracy -0.3668
# Epoch 65 Batch 300 Loss 0.0584 Accuracy -0.3515
# Epoch 65, Loss: 0.05844045430421829, Test Loss: 0.07735370099544525, Test R^2: 0.3817184567451477
# Saving checkpoint for epoch 65 at ./checkpoints_64_21_pos/train/ckpt-13
# Epoch 65 Loss 0.0584 Accuracy -0.3512
# Time taken for 1 epoch: 48.67 secs
#
# Epoch 66 Batch 0 Loss 0.0460 Accuracy -0.3511
# Epoch 66 Batch 300 Loss 0.0581 Accuracy -0.3362
# Epoch 66, Loss: 0.05807952210307121, Test Loss: 0.07712151110172272, Test R^2: 0.385570764541626
# Epoch 67 Batch 0 Loss 0.0454 Accuracy -0.3359
# Epoch 67 Batch 300 Loss 0.0577 Accuracy -0.3214
# Epoch 67, Loss: 0.05772218853235245, Test Loss: 0.07689043134450912, Test R^2: 0.3893272280693054
# Epoch 68 Batch 0 Loss 0.0437 Accuracy -0.3210
# Epoch 68 Batch 300 Loss 0.0581 Accuracy -0.3069
# Epoch 68, Loss: 0.05792202427983284, Test Loss: 0.07665839046239853, Test R^2: 0.3930051922798157
# Epoch 69 Batch 0 Loss 0.0644 Accuracy -0.3066
# Epoch 69 Batch 300 Loss 0.0577 Accuracy -0.2930
# Epoch 69, Loss: 0.05762849003076553, Test Loss: 0.07644189894199371, Test R^2: 0.396614134311676
# Epoch 70 Batch 0 Loss 0.0371 Accuracy -0.2926
# Epoch 70 Batch 300 Loss 0.0573 Accuracy -0.2793
# Epoch 70, Loss: 0.05712432786822319, Test Loss: 0.07623555511236191, Test R^2: 0.3999637961387634
# Saving checkpoint for epoch 70 at ./checkpoints_64_21_pos/train/ckpt-14
# Epoch 70 Loss 0.0571 Accuracy -0.2790
# Time taken for 1 epoch: 48.74 secs
#
# Epoch 71 Batch 0 Loss 0.0654 Accuracy -0.2790
# Epoch 71 Batch 300 Loss 0.0574 Accuracy -0.2661
# Epoch 71, Loss: 0.057280439883470535, Test Loss: 0.07603061944246292, Test R^2: 0.40331965684890747
# Epoch 72 Batch 0 Loss 0.0528 Accuracy -0.2657
# Epoch 72 Batch 300 Loss 0.0573 Accuracy -0.2532
# Epoch 72, Loss: 0.05722784250974655, Test Loss: 0.07584507018327713, Test R^2: 0.40651702880859375
# Epoch 73 Batch 0 Loss 0.0497 Accuracy -0.2529
# Epoch 73 Batch 300 Loss 0.0571 Accuracy -0.2406
# Epoch 73, Loss: 0.05727663263678551, Test Loss: 0.07566017657518387, Test R^2: 0.4097161889076233
# Epoch 74 Batch 0 Loss 0.0688 Accuracy -0.2403
# Epoch 74 Batch 300 Loss 0.0571 Accuracy -0.2284
# Epoch 74, Loss: 0.05702953785657883, Test Loss: 0.07547347992658615, Test R^2: 0.4127810597419739
# Epoch 75 Batch 0 Loss 0.0529 Accuracy -0.2280
# Epoch 75 Batch 300 Loss 0.0570 Accuracy -0.2164
# Epoch 75, Loss: 0.056824035942554474, Test Loss: 0.07528910040855408, Test R^2: 0.41587305068969727
# Saving checkpoint for epoch 75 at ./checkpoints_64_21_pos/train/ckpt-15
# Epoch 75 Loss 0.0568 Accuracy -0.2162
# Time taken for 1 epoch: 47.94 secs
#
# Epoch 76 Batch 0 Loss 0.0501 Accuracy -0.2161
# Epoch 76 Batch 300 Loss 0.0568 Accuracy -0.2047
# Epoch 76, Loss: 0.05667473375797272, Test Loss: 0.07510669529438019, Test R^2: 0.41884398460388184
# Epoch 77 Batch 0 Loss 0.0540 Accuracy -0.2045
# Epoch 77 Batch 300 Loss 0.0569 Accuracy -0.1935
# Epoch 77, Loss: 0.05672755092382431, Test Loss: 0.07493212819099426, Test R^2: 0.4217889904975891
# Epoch 78 Batch 0 Loss 0.0656 Accuracy -0.1931
# Epoch 78 Batch 300 Loss 0.0563 Accuracy -0.1824
# Epoch 78, Loss: 0.05625191330909729, Test Loss: 0.0747566819190979, Test R^2: 0.42464375495910645
# Epoch 79 Batch 0 Loss 0.0475 Accuracy -0.1821
# Epoch 79 Batch 300 Loss 0.0562 Accuracy -0.1715
# Epoch 79, Loss: 0.056137602776288986, Test Loss: 0.07459503412246704, Test R^2: 0.4273228049278259
# Epoch 80 Batch 0 Loss 0.0541 Accuracy -0.1713
# Epoch 80 Batch 300 Loss 0.0563 Accuracy -0.1610
# Epoch 80, Loss: 0.05619559809565544, Test Loss: 0.0744408518075943, Test R^2: 0.4298706650733948
# Saving checkpoint for epoch 80 at ./checkpoints_64_21_pos/train/ckpt-16
# Epoch 80 Loss 0.0562 Accuracy -0.1607
# Time taken for 1 epoch: 48.48 secs
#
# Epoch 81 Batch 0 Loss 0.0502 Accuracy -0.1607
# Epoch 81 Batch 300 Loss 0.0563 Accuracy -0.1507
# Epoch 81, Loss: 0.05619693174958229, Test Loss: 0.07427340000867844, Test R^2: 0.4325965642929077
# Epoch 82 Batch 0 Loss 0.0295 Accuracy -0.1504
# Epoch 82 Batch 300 Loss 0.0561 Accuracy -0.1405
# Epoch 82, Loss: 0.05597778409719467, Test Loss: 0.07412757724523544, Test R^2: 0.43497002124786377
# Epoch 83 Batch 0 Loss 0.0553 Accuracy -0.1404
# Epoch 83 Batch 300 Loss 0.0560 Accuracy -0.1308
# Epoch 83, Loss: 0.05608426779508591, Test Loss: 0.07397875189781189, Test R^2: 0.4374616742134094
# Epoch 84 Batch 0 Loss 0.0447 Accuracy -0.1305
# Epoch 84 Batch 300 Loss 0.0562 Accuracy -0.1212
# Epoch 84, Loss: 0.05606108531355858, Test Loss: 0.07384197413921356, Test R^2: 0.4396960735321045
# Epoch 85 Batch 0 Loss 0.0511 Accuracy -0.1209
# Epoch 85 Batch 300 Loss 0.0558 Accuracy -0.1117
# Epoch 85, Loss: 0.05566808581352234, Test Loss: 0.07370308041572571, Test R^2: 0.44206416606903076
# Saving checkpoint for epoch 85 at ./checkpoints_64_21_pos/train/ckpt-17
# Epoch 85 Loss 0.0557 Accuracy -0.1115
# Time taken for 1 epoch: 48.52 secs
#
# Epoch 86 Batch 0 Loss 0.0559 Accuracy -0.1115
# Epoch 86 Batch 300 Loss 0.0553 Accuracy -0.1025
# Epoch 86, Loss: 0.05531821772456169, Test Loss: 0.07355853170156479, Test R^2: 0.44445741176605225
# Epoch 87 Batch 0 Loss 0.0582 Accuracy -0.1022
# Epoch 87 Batch 300 Loss 0.0553 Accuracy -0.0935
# Epoch 87, Loss: 0.055385805666446686, Test Loss: 0.07340601831674576, Test R^2: 0.4468786120414734
# Epoch 88 Batch 0 Loss 0.0473 Accuracy -0.0933
# Epoch 88 Batch 300 Loss 0.0548 Accuracy -0.0847
# Epoch 88, Loss: 0.05503386631608009, Test Loss: 0.07326654344797134, Test R^2: 0.4492151141166687
# Epoch 89 Batch 0 Loss 0.0510 Accuracy -0.0844
# Epoch 89 Batch 300 Loss 0.0557 Accuracy -0.0759
# Epoch 89, Loss: 0.05534682795405388, Test Loss: 0.07312840968370438, Test R^2: 0.451479971408844
# Epoch 90 Batch 0 Loss 0.0639 Accuracy -0.0757
# Epoch 90 Batch 300 Loss 0.0551 Accuracy -0.0676
# Epoch 90, Loss: 0.055078424513339996, Test Loss: 0.07300207763910294, Test R^2: 0.4535773992538452
# Saving checkpoint for epoch 90 at ./checkpoints_64_21_pos/train/ckpt-18
# Epoch 90 Loss 0.0551 Accuracy -0.0673
# Time taken for 1 epoch: 48.75 secs
#
# Epoch 91 Batch 0 Loss 0.0422 Accuracy -0.0673
# Epoch 91 Batch 300 Loss 0.0555 Accuracy -0.0592
# Epoch 91, Loss: 0.055354759097099304, Test Loss: 0.0728733018040657, Test R^2: 0.455661416053772
# Epoch 92 Batch 0 Loss 0.0393 Accuracy -0.0591
# Epoch 92 Batch 300 Loss 0.0546 Accuracy -0.0512
# Epoch 92, Loss: 0.05459444969892502, Test Loss: 0.07274172455072403, Test R^2: 0.45775800943374634
# Epoch 93 Batch 0 Loss 0.0473 Accuracy -0.0510
# Epoch 93 Batch 300 Loss 0.0546 Accuracy -0.0433
# Epoch 93, Loss: 0.05476030334830284, Test Loss: 0.07262205332517624, Test R^2: 0.4596675634384155
# Epoch 94 Batch 0 Loss 0.0647 Accuracy -0.0431
# Epoch 94 Batch 300 Loss 0.0546 Accuracy -0.0355
# Epoch 94, Loss: 0.05453040078282356, Test Loss: 0.072503000497818, Test R^2: 0.46164679527282715
# Epoch 95 Batch 0 Loss 0.0415 Accuracy -0.0353
# Epoch 95 Batch 300 Loss 0.0549 Accuracy -0.0278
# Epoch 95, Loss: 0.05470030754804611, Test Loss: 0.07238788902759552, Test R^2: 0.46361035108566284
# Saving checkpoint for epoch 95 at ./checkpoints_64_21_pos/train/ckpt-19
# Epoch 95 Loss 0.0547 Accuracy -0.0277
# Time taken for 1 epoch: 48.46 secs
#
# Epoch 96 Batch 0 Loss 0.0591 Accuracy -0.0277
# Epoch 96 Batch 300 Loss 0.0541 Accuracy -0.0203
# Epoch 96, Loss: 0.054215170443058014, Test Loss: 0.07227399945259094, Test R^2: 0.4655042290687561
# Epoch 97 Batch 0 Loss 0.0480 Accuracy -0.0202
# Epoch 97 Batch 300 Loss 0.0547 Accuracy -0.0130
# Epoch 97, Loss: 0.0545785091817379, Test Loss: 0.07216539978981018, Test R^2: 0.46734869480133057
# Epoch 98 Batch 0 Loss 0.0531 Accuracy -0.0128
# Epoch 98 Batch 300 Loss 0.0544 Accuracy -0.0058
# Epoch 98, Loss: 0.054310668259859085, Test Loss: 0.07205440104007721, Test R^2: 0.46915459632873535
# Epoch 99 Batch 0 Loss 0.0628 Accuracy -0.0056
# Epoch 99 Batch 300 Loss 0.0541 Accuracy 0.0012
# Epoch 99, Loss: 0.054159119725227356, Test Loss: 0.07196077704429626, Test R^2: 0.4709024429321289
# Epoch 100 Batch 0 Loss 0.0660 Accuracy 0.0014
# Epoch 100 Batch 300 Loss 0.0540 Accuracy 0.0081
# Epoch 100, Loss: 0.054082274436950684, Test Loss: 0.07185039669275284, Test R^2: 0.4727340340614319
# Saving checkpoint for epoch 100 at ./checkpoints_64_21_pos/train/ckpt-20
# Epoch 100 Loss 0.0541 Accuracy 0.0083
# Time taken for 1 epoch: 47.98 secs
#
# Epoch 101 Batch 0 Loss 0.0458 Accuracy 0.0083
# Epoch 101 Batch 300 Loss 0.0541 Accuracy 0.0149
# Epoch 101, Loss: 0.05415895953774452, Test Loss: 0.07174203544855118, Test R^2: 0.47441571950912476
# Epoch 102 Batch 0 Loss 0.0666 Accuracy 0.0151
# Epoch 102 Batch 300 Loss 0.0538 Accuracy 0.0216
# Epoch 102, Loss: 0.05384870246052742, Test Loss: 0.07164155691862106, Test R^2: 0.4761245846748352
# Epoch 103 Batch 0 Loss 0.0512 Accuracy 0.0217
# Epoch 103 Batch 300 Loss 0.0537 Accuracy 0.0282
# Epoch 103, Loss: 0.05377443879842758, Test Loss: 0.0715402290225029, Test R^2: 0.477777361869812
# Epoch 104 Batch 0 Loss 0.0541 Accuracy 0.0283
# Epoch 104 Batch 300 Loss 0.0538 Accuracy 0.0346
# Epoch 104, Loss: 0.05378356948494911, Test Loss: 0.07144816219806671, Test R^2: 0.47940772771835327
# Epoch 105 Batch 0 Loss 0.0516 Accuracy 0.0347
# Epoch 105 Batch 300 Loss 0.0539 Accuracy 0.0409
# Epoch 105, Loss: 0.05373179912567139, Test Loss: 0.07134591042995453, Test R^2: 0.48107922077178955
# Saving checkpoint for epoch 105 at ./checkpoints_64_21_pos/train/ckpt-21
# Epoch 105 Loss 0.0537 Accuracy 0.0410
# Time taken for 1 epoch: 48.57 secs
#
# Epoch 106 Batch 0 Loss 0.0449 Accuracy 0.0410
# Epoch 106 Batch 300 Loss 0.0537 Accuracy 0.0471
# Epoch 106, Loss: 0.05375172197818756, Test Loss: 0.07125485688447952, Test R^2: 0.48269110918045044
# Epoch 107 Batch 0 Loss 0.0468 Accuracy 0.0472
# Epoch 107 Batch 300 Loss 0.0535 Accuracy 0.0532
# Epoch 107, Loss: 0.05351381003856659, Test Loss: 0.0711711049079895, Test R^2: 0.4842085838317871
# Epoch 108 Batch 0 Loss 0.0457 Accuracy 0.0533
# Epoch 108 Batch 300 Loss 0.0536 Accuracy 0.0592
# Epoch 108, Loss: 0.053310275077819824, Test Loss: 0.07107505202293396, Test R^2: 0.48578816652297974
# Epoch 109 Batch 0 Loss 0.0576 Accuracy 0.0593
# Epoch 109 Batch 300 Loss 0.0534 Accuracy 0.0651
# Epoch 109, Loss: 0.05341494828462601, Test Loss: 0.07099169492721558, Test R^2: 0.4872409701347351
# Epoch 110 Batch 0 Loss 0.0439 Accuracy 0.0652
# Epoch 110 Batch 300 Loss 0.0533 Accuracy 0.0708
# Epoch 110, Loss: 0.053220976144075394, Test Loss: 0.07090175896883011, Test R^2: 0.48878270387649536
# Saving checkpoint for epoch 110 at ./checkpoints_64_21_pos/train/ckpt-22
# Epoch 110 Loss 0.0532 Accuracy 0.0709
# Time taken for 1 epoch: 48.61 secs
#
# Epoch 111 Batch 0 Loss 0.0362 Accuracy 0.0709
# Epoch 111 Batch 300 Loss 0.0532 Accuracy 0.0765
# Epoch 111, Loss: 0.05309174209833145, Test Loss: 0.07080982625484467, Test R^2: 0.4902333617210388
# Epoch 112 Batch 0 Loss 0.0456 Accuracy 0.0766
# Epoch 112 Batch 300 Loss 0.0531 Accuracy 0.0821
# Epoch 112, Loss: 0.052969709038734436, Test Loss: 0.07072239369153976, Test R^2: 0.4916369915008545
# Epoch 113 Batch 0 Loss 0.0432 Accuracy 0.0822
# Epoch 113 Batch 300 Loss 0.0531 Accuracy 0.0876
# Epoch 113, Loss: 0.05308546870946884, Test Loss: 0.07064483314752579, Test R^2: 0.4930097460746765
# Epoch 114 Batch 0 Loss 0.0493 Accuracy 0.0877
# Epoch 114 Batch 300 Loss 0.0528 Accuracy 0.0930
# Epoch 114, Loss: 0.05286046862602234, Test Loss: 0.07056552171707153, Test R^2: 0.494356632232666
# Epoch 115 Batch 0 Loss 0.0545 Accuracy 0.0931
# Epoch 115 Batch 300 Loss 0.0529 Accuracy 0.0983
# Epoch 115, Loss: 0.052743762731552124, Test Loss: 0.07047519832849503, Test R^2: 0.4957844614982605
# Saving checkpoint for epoch 115 at ./checkpoints_64_21_pos/train/ckpt-23
# Epoch 115 Loss 0.0527 Accuracy 0.0984
# Time taken for 1 epoch: 48.17 secs
#
# Epoch 116 Batch 0 Loss 0.0568 Accuracy 0.0985
# Epoch 116 Batch 300 Loss 0.0528 Accuracy 0.1036
# Epoch 116, Loss: 0.05275403708219528, Test Loss: 0.0703951045870781, Test R^2: 0.4971373677253723
# Epoch 117 Batch 0 Loss 0.0479 Accuracy 0.1037
# Epoch 117 Batch 300 Loss 0.0530 Accuracy 0.1086
# Epoch 117, Loss: 0.05316675081849098, Test Loss: 0.07031644880771637, Test R^2: 0.49842578172683716
# Epoch 118 Batch 0 Loss 0.0666 Accuracy 0.1088
# Epoch 118 Batch 300 Loss 0.0527 Accuracy 0.1137
# Epoch 118, Loss: 0.05280263349413872, Test Loss: 0.0702328309416771, Test R^2: 0.4998133182525635
# Epoch 119 Batch 0 Loss 0.0657 Accuracy 0.1139
# Epoch 119 Batch 300 Loss 0.0525 Accuracy 0.1187
# Epoch 119, Loss: 0.052678223699331284, Test Loss: 0.07016152143478394, Test R^2: 0.501056969165802
# Epoch 120 Batch 0 Loss 0.0521 Accuracy 0.1188
# Epoch 120 Batch 300 Loss 0.0523 Accuracy 0.1236
# Epoch 120, Loss: 0.05234679579734802, Test Loss: 0.07008091360330582, Test R^2: 0.502326250076294
# Saving checkpoint for epoch 120 at ./checkpoints_64_21_pos/train/ckpt-24
# Epoch 120 Loss 0.0523 Accuracy 0.1237
# Time taken for 1 epoch: 48.55 secs
#
# Epoch 121 Batch 0 Loss 0.0489 Accuracy 0.1237
# Epoch 121 Batch 300 Loss 0.0523 Accuracy 0.1284
# Epoch 121, Loss: 0.0524432398378849, Test Loss: 0.06999962776899338, Test R^2: 0.5036261081695557
# Epoch 122 Batch 0 Loss 0.0423 Accuracy 0.1286
# Epoch 122 Batch 300 Loss 0.0522 Accuracy 0.1332
# Epoch 122, Loss: 0.052234992384910583, Test Loss: 0.06991873681545258, Test R^2: 0.5049059987068176
# Epoch 123 Batch 0 Loss 0.0515 Accuracy 0.1333
# Epoch 123 Batch 300 Loss 0.0522 Accuracy 0.1379
# Epoch 123, Loss: 0.052288707345724106, Test Loss: 0.06983926892280579, Test R^2: 0.5061689615249634
# Epoch 124 Batch 0 Loss 0.0370 Accuracy 0.1380
# Epoch 124 Batch 300 Loss 0.0521 Accuracy 0.1425
# Epoch 124, Loss: 0.05201110616326332, Test Loss: 0.0697692260146141, Test R^2: 0.507310152053833
# Epoch 125 Batch 0 Loss 0.0343 Accuracy 0.1426
# Epoch 125 Batch 300 Loss 0.0519 Accuracy 0.1470
# Epoch 125, Loss: 0.052079930901527405, Test Loss: 0.06970185041427612, Test R^2: 0.508483350276947
# Saving checkpoint for epoch 125 at ./checkpoints_64_21_pos/train/ckpt-25
# Epoch 125 Loss 0.0521 Accuracy 0.1472
# Time taken for 1 epoch: 48.30 secs
#
# Epoch 126 Batch 0 Loss 0.0313 Accuracy 0.1472
# Epoch 126 Batch 300 Loss 0.0518 Accuracy 0.1515
# Epoch 126, Loss: 0.05190777778625488, Test Loss: 0.06963324546813965, Test R^2: 0.5096096992492676
# Epoch 127 Batch 0 Loss 0.0357 Accuracy 0.1517
# Epoch 127 Batch 300 Loss 0.0519 Accuracy 0.1559
# Epoch 127, Loss: 0.0520545169711113, Test Loss: 0.06956330686807632, Test R^2: 0.5107442140579224
# Epoch 128 Batch 0 Loss 0.0487 Accuracy 0.1561
# Epoch 128 Batch 300 Loss 0.0520 Accuracy 0.1603
# Epoch 128, Loss: 0.051979973912239075, Test Loss: 0.06949695944786072, Test R^2: 0.5118769407272339
# Epoch 129 Batch 0 Loss 0.0403 Accuracy 0.1604
# Epoch 129 Batch 300 Loss 0.0521 Accuracy 0.1646
# Epoch 129, Loss: 0.05215068161487579, Test Loss: 0.06943554431200027, Test R^2: 0.5129371881484985
# Epoch 130 Batch 0 Loss 0.0385 Accuracy 0.1647
# Epoch 130 Batch 300 Loss 0.0519 Accuracy 0.1688
# Epoch 130, Loss: 0.05186903476715088, Test Loss: 0.06936801970005035, Test R^2: 0.5140520334243774
# Saving checkpoint for epoch 130 at ./checkpoints_64_21_pos/train/ckpt-26
# Epoch 130 Loss 0.0519 Accuracy 0.1689
# Time taken for 1 epoch: 48.62 secs
#
# Epoch 131 Batch 0 Loss 0.0481 Accuracy 0.1689
# Epoch 131 Batch 300 Loss 0.0514 Accuracy 0.1730
# Epoch 131, Loss: 0.05143681541085243, Test Loss: 0.06929866969585419, Test R^2: 0.5151705741882324
# Epoch 132 Batch 0 Loss 0.0394 Accuracy 0.1731
# Epoch 132 Batch 300 Loss 0.0518 Accuracy 0.1771
# Epoch 132, Loss: 0.05169457569718361, Test Loss: 0.06923260539770126, Test R^2: 0.5162315368652344
# Epoch 133 Batch 0 Loss 0.0564 Accuracy 0.1772
# Epoch 133 Batch 300 Loss 0.0514 Accuracy 0.1811
# Epoch 133, Loss: 0.05170740187168121, Test Loss: 0.06917504966259003, Test R^2: 0.5172179937362671
# Epoch 134 Batch 0 Loss 0.0470 Accuracy 0.1812
# Epoch 134 Batch 300 Loss 0.0513 Accuracy 0.1850
# Epoch 134, Loss: 0.051713649183511734, Test Loss: 0.06911703199148178, Test R^2: 0.5181888341903687
# Epoch 135 Batch 0 Loss 0.0478 Accuracy 0.1852
# Epoch 135 Batch 300 Loss 0.0512 Accuracy 0.1890
# Epoch 135, Loss: 0.05151142552495003, Test Loss: 0.06906373798847198, Test R^2: 0.519107460975647
# Saving checkpoint for epoch 135 at ./checkpoints_64_21_pos/train/ckpt-27
# Epoch 135 Loss 0.0515 Accuracy 0.1891
# Time taken for 1 epoch: 48.80 secs
#
# Epoch 136 Batch 0 Loss 0.0511 Accuracy 0.1892
# Epoch 136 Batch 300 Loss 0.0517 Accuracy 0.1930
# Epoch 136, Loss: 0.051591306924819946, Test Loss: 0.06900792568922043, Test R^2: 0.5200300216674805
# Epoch 137 Batch 0 Loss 0.0477 Accuracy 0.1930
# Epoch 137 Batch 300 Loss 0.0514 Accuracy 0.1968
# Epoch 137, Loss: 0.051266200840473175, Test Loss: 0.0689467117190361, Test R^2: 0.5210416913032532
# Epoch 138 Batch 0 Loss 0.0363 Accuracy 0.1969
# Epoch 138 Batch 300 Loss 0.0513 Accuracy 0.2006
# Epoch 138, Loss: 0.0513312928378582, Test Loss: 0.06888721883296967, Test R^2: 0.5220459699630737
# Epoch 139 Batch 0 Loss 0.0522 Accuracy 0.2007
# Epoch 139 Batch 300 Loss 0.0514 Accuracy 0.2043
# Epoch 139, Loss: 0.05140414461493492, Test Loss: 0.06882704794406891, Test R^2: 0.5230057835578918
# Epoch 140 Batch 0 Loss 0.0406 Accuracy 0.2044
# Epoch 140 Batch 300 Loss 0.0511 Accuracy 0.2080
# Epoch 140, Loss: 0.050984058529138565, Test Loss: 0.06877165287733078, Test R^2: 0.523959755897522
# Saving checkpoint for epoch 140 at ./checkpoints_64_21_pos/train/ckpt-28
# Epoch 140 Loss 0.0510 Accuracy 0.2080
# Time taken for 1 epoch: 45.01 secs
#
# Epoch 141 Batch 0 Loss 0.0518 Accuracy 0.2080
# Epoch 141 Batch 300 Loss 0.0515 Accuracy 0.2116
# Epoch 141, Loss: 0.05132443085312843, Test Loss: 0.06871560215950012, Test R^2: 0.5249007344245911
# Epoch 142 Batch 0 Loss 0.0395 Accuracy 0.2117
# Epoch 142 Batch 300 Loss 0.0512 Accuracy 0.2152
# Epoch 142, Loss: 0.051167041063308716, Test Loss: 0.06866065412759781, Test R^2: 0.5258253812789917
# Epoch 143 Batch 0 Loss 0.0681 Accuracy 0.2153
# Epoch 143 Batch 300 Loss 0.0508 Accuracy 0.2187
# Epoch 143, Loss: 0.05099750682711601, Test Loss: 0.06860809028148651, Test R^2: 0.5267179608345032
# Epoch 144 Batch 0 Loss 0.0332 Accuracy 0.2188
# Epoch 144 Batch 300 Loss 0.0507 Accuracy 0.2222
# Epoch 144, Loss: 0.05078351870179176, Test Loss: 0.06855174154043198, Test R^2: 0.5276362895965576
# Epoch 145 Batch 0 Loss 0.0445 Accuracy 0.2223
# Epoch 145 Batch 300 Loss 0.0508 Accuracy 0.2256
# Epoch 145, Loss: 0.050794169306755066, Test Loss: 0.0685029998421669, Test R^2: 0.5284953117370605
# Saving checkpoint for epoch 145 at ./checkpoints_64_21_pos/train/ckpt-29
# Epoch 145 Loss 0.0508 Accuracy 0.2257
# Time taken for 1 epoch: 48.53 secs
#
# Epoch 146 Batch 0 Loss 0.0525 Accuracy 0.2257
# Epoch 146 Batch 300 Loss 0.0508 Accuracy 0.2291
# Epoch 146, Loss: 0.050695568323135376, Test Loss: 0.06845105439424515, Test R^2: 0.5293564200401306
# Epoch 147 Batch 0 Loss 0.0538 Accuracy 0.2291
# Epoch 147 Batch 300 Loss 0.0507 Accuracy 0.2324
# Epoch 147, Loss: 0.050493087619543076, Test Loss: 0.06839822977781296, Test R^2: 0.5301727056503296
# Epoch 148 Batch 0 Loss 0.0403 Accuracy 0.2325
# Epoch 148 Batch 300 Loss 0.0509 Accuracy 0.2357
# Epoch 148, Loss: 0.05082985386252403, Test Loss: 0.06834850460290909, Test R^2: 0.5310244560241699
# Epoch 149 Batch 0 Loss 0.0592 Accuracy 0.2358
# Epoch 149 Batch 300 Loss 0.0509 Accuracy 0.2390
# Epoch 149, Loss: 0.0507759228348732, Test Loss: 0.06829772144556046, Test R^2: 0.5318666696548462
# Epoch 150 Batch 0 Loss 0.0431 Accuracy 0.2391
# Epoch 150 Batch 300 Loss 0.0506 Accuracy 0.2422
# Epoch 150, Loss: 0.05051274970173836, Test Loss: 0.06825203448534012, Test R^2: 0.5326542258262634
# Saving checkpoint for epoch 150 at ./checkpoints_64_21_pos/train/ckpt-30
# Epoch 150 Loss 0.0505 Accuracy 0.2423
# Time taken for 1 epoch: 48.25 secs
#
# Epoch 151 Batch 0 Loss 0.0425 Accuracy 0.2423
# Epoch 151 Batch 300 Loss 0.0505 Accuracy 0.2454
# Epoch 151, Loss: 0.050488829612731934, Test Loss: 0.06820544600486755, Test R^2: 0.5334640741348267
# Epoch 152 Batch 0 Loss 0.0345 Accuracy 0.2455
# Epoch 152 Batch 300 Loss 0.0504 Accuracy 0.2486
# Epoch 152, Loss: 0.050550393760204315, Test Loss: 0.0681593045592308, Test R^2: 0.5342389345169067
# Epoch 153 Batch 0 Loss 0.0565 Accuracy 0.2486
# Epoch 153 Batch 300 Loss 0.0505 Accuracy 0.2517
# Epoch 153, Loss: 0.050449904054403305, Test Loss: 0.06811770051717758, Test R^2: 0.5350106954574585
# Epoch 154 Batch 0 Loss 0.0424 Accuracy 0.2518
# Epoch 154 Batch 300 Loss 0.0503 Accuracy 0.2548
# Epoch 154, Loss: 0.050263796001672745, Test Loss: 0.06807373464107513, Test R^2: 0.5357649326324463
# Epoch 155 Batch 0 Loss 0.0495 Accuracy 0.2549
# Epoch 155 Batch 300 Loss 0.0504 Accuracy 0.2578
# Epoch 155, Loss: 0.05037136748433113, Test Loss: 0.06802447140216827, Test R^2: 0.5365754961967468
# Saving checkpoint for epoch 155 at ./checkpoints_64_21_pos/train/ckpt-31
# Epoch 155 Loss 0.0504 Accuracy 0.2579
# Time taken for 1 epoch: 48.61 secs
#
# Epoch 156 Batch 0 Loss 0.0570 Accuracy 0.2579
# Epoch 156 Batch 300 Loss 0.0501 Accuracy 0.2608
# Epoch 156, Loss: 0.05017922818660736, Test Loss: 0.06797786802053452, Test R^2: 0.5373309850692749
# Epoch 157 Batch 0 Loss 0.0527 Accuracy 0.2609
# Epoch 157 Batch 300 Loss 0.0499 Accuracy 0.2637
# Epoch 157, Loss: 0.050211433321237564, Test Loss: 0.0679543986916542, Test R^2: 0.5379148721694946
# Epoch 158 Batch 0 Loss 0.0530 Accuracy 0.2639
# Epoch 158 Batch 300 Loss 0.0499 Accuracy 0.2667
# Epoch 158, Loss: 0.0498933345079422, Test Loss: 0.06790895760059357, Test R^2: 0.5386751890182495
# Epoch 159 Batch 0 Loss 0.0636 Accuracy 0.2668
# Epoch 159 Batch 300 Loss 0.0502 Accuracy 0.2696
# Epoch 159, Loss: 0.050248343497514725, Test Loss: 0.06786645203828812, Test R^2: 0.5393970012664795
# Epoch 160 Batch 0 Loss 0.0527 Accuracy 0.2697
# Epoch 160 Batch 300 Loss 0.0501 Accuracy 0.2725
# Epoch 160, Loss: 0.04993029311299324, Test Loss: 0.06782348453998566, Test R^2: 0.5400962829589844
# Saving checkpoint for epoch 160 at ./checkpoints_64_21_pos/train/ckpt-32
# Epoch 160 Loss 0.0499 Accuracy 0.2725
# Time taken for 1 epoch: 48.70 secs
#
# Epoch 161 Batch 0 Loss 0.0467 Accuracy 0.2725
# Epoch 161 Batch 300 Loss 0.0498 Accuracy 0.2753
# Epoch 161, Loss: 0.04986346513032913, Test Loss: 0.06778238713741302, Test R^2: 0.5408027172088623
# Epoch 162 Batch 0 Loss 0.0339 Accuracy 0.2754
# Epoch 162 Batch 300 Loss 0.0499 Accuracy 0.2781
# Epoch 162, Loss: 0.04992086812853813, Test Loss: 0.0677378922700882, Test R^2: 0.5415067672729492
# Epoch 163 Batch 0 Loss 0.0409 Accuracy 0.2781
# Epoch 163 Batch 300 Loss 0.0499 Accuracy 0.2808
# Epoch 163, Loss: 0.05004662647843361, Test Loss: 0.06770709156990051, Test R^2: 0.542141318321228
# Epoch 164 Batch 0 Loss 0.0358 Accuracy 0.2809
# Epoch 164 Batch 300 Loss 0.0498 Accuracy 0.2835
# Epoch 164, Loss: 0.0498543456196785, Test Loss: 0.06766405701637268, Test R^2: 0.542839527130127
# Epoch 165 Batch 0 Loss 0.0587 Accuracy 0.2836
# Epoch 165 Batch 300 Loss 0.0501 Accuracy 0.2862
# Epoch 165, Loss: 0.049998655915260315, Test Loss: 0.06762340664863586, Test R^2: 0.5434674024581909
# Saving checkpoint for epoch 165 at ./checkpoints_64_21_pos/train/ckpt-33
# Epoch 165 Loss 0.0500 Accuracy 0.2863
# Time taken for 1 epoch: 48.72 secs
#
# Epoch 166 Batch 0 Loss 0.0479 Accuracy 0.2863
# Epoch 166 Batch 300 Loss 0.0498 Accuracy 0.2889
# Epoch 166, Loss: 0.04996353015303612, Test Loss: 0.06759122014045715, Test R^2: 0.544091522693634
# Epoch 167 Batch 0 Loss 0.0662 Accuracy 0.2890
# Epoch 167 Batch 300 Loss 0.0499 Accuracy 0.2915
# Epoch 167, Loss: 0.049893949180841446, Test Loss: 0.06754804402589798, Test R^2: 0.5447649955749512
# Epoch 168 Batch 0 Loss 0.0334 Accuracy 0.2916
# Epoch 168 Batch 300 Loss 0.0494 Accuracy 0.2941
# Epoch 168, Loss: 0.049623988568782806, Test Loss: 0.06750589609146118, Test R^2: 0.5454556941986084
# Epoch 169 Batch 0 Loss 0.0348 Accuracy 0.2942
# Epoch 169 Batch 300 Loss 0.0496 Accuracy 0.2967
# Epoch 169, Loss: 0.049800824373960495, Test Loss: 0.06746579706668854, Test R^2: 0.5461245775222778
# Epoch 170 Batch 0 Loss 0.0491 Accuracy 0.2967
# Epoch 170 Batch 300 Loss 0.0498 Accuracy 0.2992
# Epoch 170, Loss: 0.04976740851998329, Test Loss: 0.06742773205041885, Test R^2: 0.5467503070831299
# Saving checkpoint for epoch 170 at ./checkpoints_64_21_pos/train/ckpt-34
# Epoch 170 Loss 0.0498 Accuracy 0.2993
# Time taken for 1 epoch: 48.70 secs
#
# Epoch 171 Batch 0 Loss 0.0427 Accuracy 0.2993
# Epoch 171 Batch 300 Loss 0.0497 Accuracy 0.3017
# Epoch 171, Loss: 0.04960593953728676, Test Loss: 0.06739377975463867, Test R^2: 0.5473471879959106
# Epoch 172 Batch 0 Loss 0.0528 Accuracy 0.3018
# Epoch 172 Batch 300 Loss 0.0494 Accuracy 0.3042
# Epoch 172, Loss: 0.049397945404052734, Test Loss: 0.06735332310199738, Test R^2: 0.5479931831359863
# Epoch 173 Batch 0 Loss 0.0539 Accuracy 0.3043
# Epoch 173 Batch 300 Loss 0.0498 Accuracy 0.3067
# Epoch 173, Loss: 0.04974444583058357, Test Loss: 0.06731484085321426, Test R^2: 0.5486295819282532
# Epoch 174 Batch 0 Loss 0.0360 Accuracy 0.3067
# Epoch 174 Batch 300 Loss 0.0491 Accuracy 0.3091
# Epoch 174, Loss: 0.0491100549697876, Test Loss: 0.06727859377861023, Test R^2: 0.5492322444915771
# Epoch 175 Batch 0 Loss 0.0464 Accuracy 0.3092
# Epoch 175 Batch 300 Loss 0.0493 Accuracy 0.3115
# Epoch 175, Loss: 0.04920356720685959, Test Loss: 0.06723906099796295, Test R^2: 0.5498554110527039
# Saving checkpoint for epoch 175 at ./checkpoints_64_21_pos/train/ckpt-35
# Epoch 175 Loss 0.0492 Accuracy 0.3116
# Time taken for 1 epoch: 48.21 secs
#
# Epoch 176 Batch 0 Loss 0.0373 Accuracy 0.3116
# Epoch 176 Batch 300 Loss 0.0493 Accuracy 0.3139
# Epoch 176, Loss: 0.04934339597821236, Test Loss: 0.06720319390296936, Test R^2: 0.5504544973373413
# Epoch 177 Batch 0 Loss 0.0430 Accuracy 0.3140
# Epoch 177 Batch 300 Loss 0.0498 Accuracy 0.3163
# Epoch 177, Loss: 0.04966304451227188, Test Loss: 0.06716889888048172, Test R^2: 0.551048994064331
# Epoch 178 Batch 0 Loss 0.0478 Accuracy 0.3163
# Epoch 178 Batch 300 Loss 0.0493 Accuracy 0.3186
# Epoch 178, Loss: 0.04931424558162689, Test Loss: 0.06713439524173737, Test R^2: 0.5515954494476318
# Epoch 179 Batch 0 Loss 0.0347 Accuracy 0.3187
# Epoch 179 Batch 300 Loss 0.0494 Accuracy 0.3209
# Epoch 179, Loss: 0.04927098751068115, Test Loss: 0.06710579991340637, Test R^2: 0.5521332025527954
# Epoch 180 Batch 0 Loss 0.0423 Accuracy 0.3210
# Epoch 180 Batch 300 Loss 0.0492 Accuracy 0.3232
# Epoch 180, Loss: 0.049327149987220764, Test Loss: 0.06707164645195007, Test R^2: 0.5527224540710449
# Saving checkpoint for epoch 180 at ./checkpoints_64_21_pos/train/ckpt-36
# Epoch 180 Loss 0.0493 Accuracy 0.3232
# Time taken for 1 epoch: 48.29 secs
#
# Epoch 181 Batch 0 Loss 0.0594 Accuracy 0.3233
# Epoch 181 Batch 300 Loss 0.0494 Accuracy 0.3255
# Epoch 181, Loss: 0.0492987297475338, Test Loss: 0.06703539937734604, Test R^2: 0.5532838702201843
# Epoch 182 Batch 0 Loss 0.0485 Accuracy 0.3255
# Epoch 182 Batch 300 Loss 0.0492 Accuracy 0.3277
# Epoch 182, Loss: 0.04915435612201691, Test Loss: 0.06699953228235245, Test R^2: 0.5538496971130371
# Epoch 183 Batch 0 Loss 0.0439 Accuracy 0.3277
# Epoch 183 Batch 300 Loss 0.0488 Accuracy 0.3299
# Epoch 183, Loss: 0.04881149157881737, Test Loss: 0.06696833670139313, Test R^2: 0.5543739795684814
# Epoch 184 Batch 0 Loss 0.0320 Accuracy 0.3300
# Epoch 184 Batch 300 Loss 0.0494 Accuracy 0.3321
# Epoch 184, Loss: 0.049189697951078415, Test Loss: 0.06693927943706512, Test R^2: 0.5548853874206543
# Epoch 185 Batch 0 Loss 0.0401 Accuracy 0.3322
# Epoch 185 Batch 300 Loss 0.0489 Accuracy 0.3343
# Epoch 185, Loss: 0.04904565215110779, Test Loss: 0.06690973043441772, Test R^2: 0.5553737878799438
# Saving checkpoint for epoch 185 at ./checkpoints_64_21_pos/train/ckpt-37
# Epoch 185 Loss 0.0490 Accuracy 0.3343
# Time taken for 1 epoch: 48.92 secs
#
# Epoch 186 Batch 0 Loss 0.0419 Accuracy 0.3343
# Epoch 186 Batch 300 Loss 0.0488 Accuracy 0.3364
# Epoch 186, Loss: 0.04883837699890137, Test Loss: 0.06687815487384796, Test R^2: 0.5558942556381226
# Epoch 187 Batch 0 Loss 0.0456 Accuracy 0.3365
# Epoch 187 Batch 300 Loss 0.0491 Accuracy 0.3386
# Epoch 187, Loss: 0.04902885481715202, Test Loss: 0.06684215366840363, Test R^2: 0.5564597845077515
# Epoch 188 Batch 0 Loss 0.0481 Accuracy 0.3386
# Epoch 188 Batch 300 Loss 0.0485 Accuracy 0.3407
# Epoch 188, Loss: 0.04862861707806587, Test Loss: 0.0668109729886055, Test R^2: 0.5569689869880676
# Epoch 189 Batch 0 Loss 0.0371 Accuracy 0.3407
# Epoch 189 Batch 300 Loss 0.0491 Accuracy 0.3428
# Epoch 189, Loss: 0.04891316965222359, Test Loss: 0.06677817553281784, Test R^2: 0.5574946403503418
# Epoch 190 Batch 0 Loss 0.0338 Accuracy 0.3428
# Epoch 190 Batch 300 Loss 0.0486 Accuracy 0.3448
# Epoch 190, Loss: 0.04864981025457382, Test Loss: 0.06674553453922272, Test R^2: 0.5580189824104309
# Saving checkpoint for epoch 190 at ./checkpoints_64_21_pos/train/ckpt-38
# Epoch 190 Loss 0.0486 Accuracy 0.3449
# Time taken for 1 epoch: 48.43 secs
#
# Epoch 191 Batch 0 Loss 0.0412 Accuracy 0.3449
# Epoch 191 Batch 300 Loss 0.0486 Accuracy 0.3469
# Epoch 191, Loss: 0.04860442504286766, Test Loss: 0.06671516597270966, Test R^2: 0.5584970712661743
# Epoch 192 Batch 0 Loss 0.0319 Accuracy 0.3469
# Epoch 192 Batch 300 Loss 0.0491 Accuracy 0.3489
# Epoch 192, Loss: 0.048997912555933, Test Loss: 0.06668625771999359, Test R^2: 0.5589556694030762
# Epoch 193 Batch 0 Loss 0.0495 Accuracy 0.3490
# Epoch 193 Batch 300 Loss 0.0489 Accuracy 0.3509
# Epoch 193, Loss: 0.048729635775089264, Test Loss: 0.06665658950805664, Test R^2: 0.5594318509101868
# Epoch 194 Batch 0 Loss 0.0425 Accuracy 0.3510
# Epoch 194 Batch 300 Loss 0.0486 Accuracy 0.3529
# Epoch 194, Loss: 0.04863428324460983, Test Loss: 0.06662607192993164, Test R^2: 0.5599050521850586
# Epoch 195 Batch 0 Loss 0.0364 Accuracy 0.3529
# Epoch 195 Batch 300 Loss 0.0485 Accuracy 0.3549
# Epoch 195, Loss: 0.04866498336195946, Test Loss: 0.0665963664650917, Test R^2: 0.5603760480880737
# Saving checkpoint for epoch 195 at ./checkpoints_64_21_pos/train/ckpt-39
# Epoch 195 Loss 0.0487 Accuracy 0.3549
# Time taken for 1 epoch: 48.76 secs
#
# Epoch 196 Batch 0 Loss 0.0358 Accuracy 0.3549
# Epoch 196 Batch 300 Loss 0.0489 Accuracy 0.3568
# Epoch 196, Loss: 0.04875633493065834, Test Loss: 0.06656712293624878, Test R^2: 0.5608394145965576
# Epoch 197 Batch 0 Loss 0.0331 Accuracy 0.3569
# Epoch 197 Batch 300 Loss 0.0486 Accuracy 0.3587
# Epoch 197, Loss: 0.048719946295022964, Test Loss: 0.06653746962547302, Test R^2: 0.561308741569519
# Epoch 198 Batch 0 Loss 0.0374 Accuracy 0.3588
# Epoch 198 Batch 300 Loss 0.0487 Accuracy 0.3607
# Epoch 198, Loss: 0.04860937222838402, Test Loss: 0.06650590896606445, Test R^2: 0.5618016719818115
# Epoch 199 Batch 0 Loss 0.0338 Accuracy 0.3607
# Epoch 199 Batch 300 Loss 0.0484 Accuracy 0.3625
# Epoch 199, Loss: 0.048485130071640015, Test Loss: 0.06648531556129456, Test R^2: 0.5622004270553589
# Epoch 200 Batch 0 Loss 0.0453 Accuracy 0.3626
# Epoch 200 Batch 300 Loss 0.0483 Accuracy 0.3644
# Epoch 200, Loss: 0.04837433248758316, Test Loss: 0.06645531952381134, Test R^2: 0.5626845359802246
# Saving checkpoint for epoch 200 at ./checkpoints_64_21_pos/train/ckpt-40
# Epoch 200 Loss 0.0484 Accuracy 0.3645
# Time taken for 1 epoch: 48.35 secs
#
# Epoch 201 Batch 0 Loss 0.0488 Accuracy 0.3645
# Epoch 201 Batch 300 Loss 0.0479 Accuracy 0.3663
# Epoch 201, Loss: 0.04822690784931183, Test Loss: 0.06642816215753555, Test R^2: 0.5631574988365173
# Epoch 202 Batch 0 Loss 0.0488 Accuracy 0.3663
# Epoch 202 Batch 300 Loss 0.0483 Accuracy 0.3682
# Epoch 202, Loss: 0.04825766384601593, Test Loss: 0.06640118360519409, Test R^2: 0.563585638999939
# Epoch 203 Batch 0 Loss 0.0335 Accuracy 0.3682
# Epoch 203 Batch 300 Loss 0.0484 Accuracy 0.3700
# Epoch 203, Loss: 0.048469170928001404, Test Loss: 0.06637632101774216, Test R^2: 0.5640079379081726
# Epoch 204 Batch 0 Loss 0.0429 Accuracy 0.3700
# Epoch 204 Batch 300 Loss 0.0485 Accuracy 0.3718
# Epoch 204, Loss: 0.04838138446211815, Test Loss: 0.06635022163391113, Test R^2: 0.5644524097442627
# Epoch 205 Batch 0 Loss 0.0353 Accuracy 0.3718
# Epoch 205 Batch 300 Loss 0.0481 Accuracy 0.3736
# Epoch 205, Loss: 0.04815603792667389, Test Loss: 0.06632519513368607, Test R^2: 0.5648748874664307
# Saving checkpoint for epoch 205 at ./checkpoints_64_21_pos/train/ckpt-41
# Epoch 205 Loss 0.0482 Accuracy 0.3736
# Time taken for 1 epoch: 48.67 secs
#
# Epoch 206 Batch 0 Loss 0.0443 Accuracy 0.3736
# Epoch 206 Batch 300 Loss 0.0479 Accuracy 0.3754
# Epoch 206, Loss: 0.04792943224310875, Test Loss: 0.06629881262779236, Test R^2: 0.5653197765350342
# Epoch 207 Batch 0 Loss 0.0340 Accuracy 0.3754
# Epoch 207 Batch 300 Loss 0.0481 Accuracy 0.3771
# Epoch 207, Loss: 0.04826632887125015, Test Loss: 0.06627091020345688, Test R^2: 0.5657528638839722
# Epoch 208 Batch 0 Loss 0.0608 Accuracy 0.3772
# Epoch 208 Batch 300 Loss 0.0482 Accuracy 0.3789
# Epoch 208, Loss: 0.048163630068302155, Test Loss: 0.06624548137187958, Test R^2: 0.5661667585372925
# Epoch 209 Batch 0 Loss 0.0345 Accuracy 0.3789
# Epoch 209 Batch 300 Loss 0.0484 Accuracy 0.3806
# Epoch 209, Loss: 0.048254914581775665, Test Loss: 0.06621995568275452, Test R^2: 0.566564679145813
# Epoch 210 Batch 0 Loss 0.0495 Accuracy 0.3807
# Epoch 210 Batch 300 Loss 0.0481 Accuracy 0.3823
# Epoch 210, Loss: 0.048182494938373566, Test Loss: 0.06619779765605927, Test R^2: 0.5669625997543335
# Saving checkpoint for epoch 210 at ./checkpoints_64_21_pos/train/ckpt-42
# Epoch 210 Loss 0.0482 Accuracy 0.3824
# Time taken for 1 epoch: 48.47 secs
#
# Epoch 211 Batch 0 Loss 0.0309 Accuracy 0.3824
# Epoch 211 Batch 300 Loss 0.0481 Accuracy 0.3840
# Epoch 211, Loss: 0.04805754870176315, Test Loss: 0.06617379933595657, Test R^2: 0.5673637390136719
# Epoch 212 Batch 0 Loss 0.0313 Accuracy 0.3841
# Epoch 212 Batch 300 Loss 0.0482 Accuracy 0.3857
# Epoch 212, Loss: 0.048203110694885254, Test Loss: 0.06614960730075836, Test R^2: 0.5677721500396729
# Epoch 213 Batch 0 Loss 0.0415 Accuracy 0.3858
# Epoch 213 Batch 300 Loss 0.0479 Accuracy 0.3874
# Epoch 213, Loss: 0.048080895096063614, Test Loss: 0.06612512469291687, Test R^2: 0.568168044090271
# Epoch 214 Batch 0 Loss 0.0458 Accuracy 0.3874
# Epoch 214 Batch 300 Loss 0.0482 Accuracy 0.3891
# Epoch 214, Loss: 0.04809161648154259, Test Loss: 0.0661022961139679, Test R^2: 0.5685625076293945
# Epoch 215 Batch 0 Loss 0.0423 Accuracy 0.3891
# Epoch 215 Batch 300 Loss 0.0478 Accuracy 0.3907
# Epoch 215, Loss: 0.04778169095516205, Test Loss: 0.06608052551746368, Test R^2: 0.5689183473587036
# Saving checkpoint for epoch 215 at ./checkpoints_64_21_pos/train/ckpt-43
# Epoch 215 Loss 0.0478 Accuracy 0.3907
# Time taken for 1 epoch: 48.75 secs
#
# Epoch 216 Batch 0 Loss 0.0450 Accuracy 0.3907
# Epoch 216 Batch 300 Loss 0.0481 Accuracy 0.3923
# Epoch 216, Loss: 0.04803772643208504, Test Loss: 0.06605962663888931, Test R^2: 0.569279134273529
# Epoch 217 Batch 0 Loss 0.0305 Accuracy 0.3924
# ...
# Epoch 230 Batch 0 Loss 0.0386 Accuracy 0.4123
# Epoch 230 Batch 300 Loss 0.0474 Accuracy 0.4138
# Epoch 230, Loss: 0.04744424670934677, Test Loss: 0.06576284021139145, Test R^2: 0.574216902256012
# Saving checkpoint for epoch 230 at ./checkpoints_64_21_pos/train/ckpt-46
# Epoch 230 Loss 0.0474 Accuracy 0.4138
# Time taken for 1 epoch: 39.01 secs
#
# Epoch 231 Batch 0 Loss 0.0557 Accuracy 0.4138
# Epoch 231 Batch 300 Loss 0.0474 Accuracy 0.4152
# Epoch 231, Loss: 0.0473625510931015, Test Loss: 0.0657411739230156, Test R^2: 0.5745671987533569
# Epoch 232 Batch 0 Loss 0.0599 Accuracy 0.4152
# Epoch 232 Batch 300 Loss 0.0474 Accuracy 0.4166
# Epoch 232, Loss: 0.047480978071689606, Test Loss: 0.06571850925683975, Test R^2: 0.5749272704124451
# Epoch 233 Batch 0 Loss 0.0434 Accuracy 0.4167
# Epoch 233 Batch 300 Loss 0.0473 Accuracy 0.4180
# Epoch 233, Loss: 0.047506965696811676, Test Loss: 0.06570073217153549, Test R^2: 0.5752519369125366
# Epoch 234 Batch 0 Loss 0.0339 Accuracy 0.4181
# Epoch 234 Batch 300 Loss 0.0473 Accuracy 0.4195
# Epoch 234, Loss: 0.04727204516530037, Test Loss: 0.0656794086098671, Test R^2: 0.5755913257598877
# Epoch 235 Batch 0 Loss 0.0349 Accuracy 0.4195
# Epoch 235 Batch 300 Loss 0.0473 Accuracy 0.4209
# Epoch 235, Loss: 0.047218240797519684, Test Loss: 0.06565900892019272, Test R^2: 0.575922966003418
# Saving checkpoint for epoch 235 at ./checkpoints_64_21_pos/train/ckpt-47
# Epoch 235 Loss 0.0472 Accuracy 0.4209
# Time taken for 1 epoch: 47.59 secs
#
# Epoch 236 Batch 0 Loss 0.0323 Accuracy 0.4209
# Epoch 236 Batch 300 Loss 0.0471 Accuracy 0.4223
# Epoch 236, Loss: 0.047124769538640976, Test Loss: 0.06563831120729446, Test R^2: 0.576246976852417
# Epoch 237 Batch 0 Loss 0.0372 Accuracy 0.4223
# Epoch 237 Batch 300 Loss 0.0469 Accuracy 0.4236
# Epoch 237, Loss: 0.047138605266809464, Test Loss: 0.06562139093875885, Test R^2: 0.5765397548675537
# Epoch 238 Batch 0 Loss 0.0270 Accuracy 0.4237
# Epoch 238 Batch 300 Loss 0.0472 Accuracy 0.4250
# Epoch 238, Loss: 0.04707659035921097, Test Loss: 0.06560298800468445, Test R^2: 0.5768452882766724
# Epoch 239 Batch 0 Loss 0.0443 Accuracy 0.4250
# Epoch 239 Batch 300 Loss 0.0474 Accuracy 0.4263
# Epoch 239, Loss: 0.04750489071011543, Test Loss: 0.0655820220708847, Test R^2: 0.5771828889846802
# Epoch 240 Batch 0 Loss 0.0350 Accuracy 0.4264
# Epoch 240 Batch 300 Loss 0.0470 Accuracy 0.4277
# Epoch 240, Loss: 0.04720824584364891, Test Loss: 0.06556150317192078, Test R^2: 0.5775125026702881
# Saving checkpoint for epoch 240 at ./checkpoints_64_21_pos/train/ckpt-48
# Epoch 240 Loss 0.0472 Accuracy 0.4277
# Time taken for 1 epoch: 47.41 secs
#
# Epoch 241 Batch 0 Loss 0.0476 Accuracy 0.4277
# Epoch 241 Batch 300 Loss 0.0471 Accuracy 0.4290
# Epoch 241, Loss: 0.047120340168476105, Test Loss: 0.06553881615400314, Test R^2: 0.5778506398200989
# Epoch 242 Batch 0 Loss 0.0492 Accuracy 0.4291
# Epoch 242 Batch 300 Loss 0.0470 Accuracy 0.4303
# Epoch 242, Loss: 0.04709459841251373, Test Loss: 0.06551960855722427, Test R^2: 0.5781485438346863
# Epoch 243 Batch 0 Loss 0.0500 Accuracy 0.4304
# Epoch 243 Batch 300 Loss 0.0473 Accuracy 0.4316
# Epoch 243, Loss: 0.047161806374788284, Test Loss: 0.06550092250108719, Test R^2: 0.5784479975700378
# Epoch 244 Batch 0 Loss 0.0309 Accuracy 0.4317
# Epoch 244 Batch 300 Loss 0.0467 Accuracy 0.4330
# Epoch 244, Loss: 0.04681171476840973, Test Loss: 0.06548371911048889, Test R^2: 0.5787304043769836
# Epoch 245 Batch 0 Loss 0.0381 Accuracy 0.4330
# Epoch 245 Batch 300 Loss 0.0471 Accuracy 0.4342
# Epoch 245, Loss: 0.04701217636466026, Test Loss: 0.0654674768447876, Test R^2: 0.5790139436721802
# Saving checkpoint for epoch 245 at ./checkpoints_64_21_pos/train/ckpt-49
# Epoch 245 Loss 0.0470 Accuracy 0.4343
# Time taken for 1 epoch: 40.76 secs
#
# Epoch 246 Batch 0 Loss 0.0453 Accuracy 0.4343
# Epoch 246 Batch 300 Loss 0.0470 Accuracy 0.4355
# Epoch 246, Loss: 0.04711756855249405, Test Loss: 0.06544924527406693, Test R^2: 0.5793215036392212
# Epoch 247 Batch 0 Loss 0.0443 Accuracy 0.4356
# Epoch 247 Batch 300 Loss 0.0471 Accuracy 0.4368
# Epoch 247, Loss: 0.0471976213157177, Test Loss: 0.06542981415987015, Test R^2: 0.5796279907226562
# Epoch 248 Batch 0 Loss 0.0383 Accuracy 0.4368
# Epoch 248 Batch 300 Loss 0.0471 Accuracy 0.4381
# Epoch 248, Loss: 0.04716908931732178, Test Loss: 0.0654103085398674, Test R^2: 0.5799412727355957
# Epoch 249 Batch 0 Loss 0.0306 Accuracy 0.4381
# Epoch 249 Batch 300 Loss 0.0467 Accuracy 0.4393
# Epoch 249, Loss: 0.04674302786588669, Test Loss: 0.06539018452167511, Test R^2: 0.5802439451217651
# Epoch 250 Batch 0 Loss 0.0462 Accuracy 0.4393
# Epoch 250 Batch 300 Loss 0.0469 Accuracy 0.4405
# Epoch 250, Loss: 0.04697590693831444, Test Loss: 0.06537330150604248, Test R^2: 0.5805279016494751
# Saving checkpoint for epoch 250 at ./checkpoints_64_21_pos/train/ckpt-50
# Epoch 250 Loss 0.0470 Accuracy 0.4406
# Time taken for 1 epoch: 44.97 secs
#
# Epoch 251 Batch 0 Loss 0.0442 Accuracy 0.4406
# Epoch 251 Batch 300 Loss 0.0466 Accuracy 0.4418
# Epoch 251, Loss: 0.04672616720199585, Test Loss: 0.06535802036523819, Test R^2: 0.5808041095733643
# Epoch 252 Batch 0 Loss 0.0486 Accuracy 0.4418
# Epoch 252 Batch 300 Loss 0.0469 Accuracy 0.4430
# Epoch 252, Loss: 0.046802498400211334, Test Loss: 0.06534445285797119, Test R^2: 0.5810443162918091
# Epoch 253 Batch 0 Loss 0.0350 Accuracy 0.4430
# Epoch 253 Batch 300 Loss 0.0472 Accuracy 0.4442
# Epoch 253, Loss: 0.04709061607718468, Test Loss: 0.06532688438892365, Test R^2: 0.5813294053077698
# Epoch 254 Batch 0 Loss 0.0365 Accuracy 0.4442
# Epoch 254 Batch 300 Loss 0.0465 Accuracy 0.4454
# Epoch 254, Loss: 0.04671430587768555, Test Loss: 0.06531429290771484, Test R^2: 0.5815805196762085
# Epoch 255 Batch 0 Loss 0.0510 Accuracy 0.4455
# Epoch 255 Batch 300 Loss 0.0465 Accuracy 0.4466
# Epoch 255, Loss: 0.04685746878385544, Test Loss: 0.0653064027428627, Test R^2: 0.5817947387695312
# Saving checkpoint for epoch 255 at ./checkpoints_64_21_pos/train/ckpt-51
# Epoch 255 Loss 0.0469 Accuracy 0.4467
# Time taken for 1 epoch: 44.02 secs
#
# Epoch 256 Batch 0 Loss 0.0508 Accuracy 0.4467
# Epoch 256 Batch 300 Loss 0.0468 Accuracy 0.4478
# Epoch 256, Loss: 0.04687711223959923, Test Loss: 0.0652911514043808, Test R^2: 0.5820583701133728
# Epoch 257 Batch 0 Loss 0.0351 Accuracy 0.4478
# Epoch 257 Batch 300 Loss 0.0465 Accuracy 0.4490
# Epoch 257, Loss: 0.046618420630693436, Test Loss: 0.06527592986822128, Test R^2: 0.5823273658752441
# Epoch 258 Batch 0 Loss 0.0457 Accuracy 0.4490
# Epoch 258 Batch 300 Loss 0.0468 Accuracy 0.4502
# Epoch 258, Loss: 0.046662524342536926, Test Loss: 0.06525803357362747, Test R^2: 0.5826183557510376
# Epoch 259 Batch 0 Loss 0.0486 Accuracy 0.4502
# Epoch 259 Batch 300 Loss 0.0468 Accuracy 0.4514
# Epoch 259, Loss: 0.046788740903139114, Test Loss: 0.06524427235126495, Test R^2: 0.5828662514686584
# Epoch 260 Batch 0 Loss 0.0373 Accuracy 0.4514
# Epoch 260 Batch 300 Loss 0.0468 Accuracy 0.4525
# Epoch 260, Loss: 0.046752817928791046, Test Loss: 0.06522946804761887, Test R^2: 0.5831224918365479
# Saving checkpoint for epoch 260 at ./checkpoints_64_21_pos/train/ckpt-52
# Epoch 260 Loss 0.0468 Accuracy 0.4525
# Time taken for 1 epoch: 45.15 secs
#
# Epoch 261 Batch 0 Loss 0.0394 Accuracy 0.4525
# Epoch 261 Batch 300 Loss 0.0467 Accuracy 0.4537
# Epoch 261, Loss: 0.046866800636053085, Test Loss: 0.06521148234605789, Test R^2: 0.583402693271637
# Epoch 262 Batch 0 Loss 0.0349 Accuracy 0.4537
# Epoch 262 Batch 300 Loss 0.0467 Accuracy 0.4548
# Epoch 262, Loss: 0.046722058206796646, Test Loss: 0.06519363820552826, Test R^2: 0.5836849212646484
# Epoch 263 Batch 0 Loss 0.0457 Accuracy 0.4548
# Epoch 263 Batch 300 Loss 0.0465 Accuracy 0.4559
# Epoch 263, Loss: 0.04640945792198181, Test Loss: 0.06518053263425827, Test R^2: 0.583927571773529
# Epoch 264 Batch 0 Loss 0.0293 Accuracy 0.4559
# Epoch 264 Batch 300 Loss 0.0467 Accuracy 0.4570
# Epoch 264, Loss: 0.04675940051674843, Test Loss: 0.06516716629266739, Test R^2: 0.584174633026123
# Epoch 265 Batch 0 Loss 0.0471 Accuracy 0.4571
# Epoch 265 Batch 300 Loss 0.0465 Accuracy 0.4582
# Epoch 265, Loss: 0.046422503888607025, Test Loss: 0.06515064090490341, Test R^2: 0.5844469666481018
# Saving checkpoint for epoch 265 at ./checkpoints_64_21_pos/train/ckpt-53
# Epoch 265 Loss 0.0464 Accuracy 0.4582
# Time taken for 1 epoch: 33.28 secs
#
# Epoch 266 Batch 0 Loss 0.0448 Accuracy 0.4582
# Epoch 266 Batch 300 Loss 0.0467 Accuracy 0.4593
# Epoch 266, Loss: 0.046708546578884125, Test Loss: 0.06513707339763641, Test R^2: 0.5846815705299377
# Epoch 267 Batch 0 Loss 0.0290 Accuracy 0.4593
# Epoch 267 Batch 300 Loss 0.0462 Accuracy 0.4603
# Epoch 267, Loss: 0.046500034630298615, Test Loss: 0.06512455642223358, Test R^2: 0.584913432598114
# Epoch 268 Batch 0 Loss 0.0310 Accuracy 0.4604
# Epoch 268 Batch 300 Loss 0.0466 Accuracy 0.4615
# Epoch 268, Loss: 0.04671446233987808, Test Loss: 0.06510920077562332, Test R^2: 0.5851789712905884
# Epoch 269 Batch 0 Loss 0.0566 Accuracy 0.4615
# Epoch 269 Batch 300 Loss 0.0464 Accuracy 0.4626
# Epoch 269, Loss: 0.046467699110507965, Test Loss: 0.06509540975093842, Test R^2: 0.5854169130325317
# Epoch 270 Batch 0 Loss 0.0551 Accuracy 0.4626
# Epoch 270 Batch 300 Loss 0.0464 Accuracy 0.4636
# Epoch 270, Loss: 0.046478159725666046, Test Loss: 0.06508094072341919, Test R^2: 0.5856506824493408
# Saving checkpoint for epoch 270 at ./checkpoints_64_21_pos/train/ckpt-54
# Epoch 270 Loss 0.0465 Accuracy 0.4637
# Time taken for 1 epoch: 37.68 secs
#
# Epoch 271 Batch 0 Loss 0.0436 Accuracy 0.4637
# Epoch 271 Batch 300 Loss 0.0462 Accuracy 0.4647
# Epoch 271, Loss: 0.046523045748472214, Test Loss: 0.06506679207086563, Test R^2: 0.5859028100967407
# Epoch 272 Batch 0 Loss 0.0438 Accuracy 0.4647
# Epoch 272 Batch 300 Loss 0.0464 Accuracy 0.4658
# Epoch 272, Loss: 0.04638020694255829, Test Loss: 0.06505228579044342, Test R^2: 0.5861493349075317
# Epoch 273 Batch 0 Loss 0.0433 Accuracy 0.4658
# Epoch 273 Batch 300 Loss 0.0463 Accuracy 0.4668
# Epoch 273, Loss: 0.046339817345142365, Test Loss: 0.06503748148679733, Test R^2: 0.5863942503929138
# Epoch 274 Batch 0 Loss 0.0466 Accuracy 0.4669
# Epoch 274 Batch 300 Loss 0.0464 Accuracy 0.4679
# Epoch 274, Loss: 0.04642244800925255, Test Loss: 0.06502388417720795, Test R^2: 0.5866181254386902
# Epoch 275 Batch 0 Loss 0.0366 Accuracy 0.4679
# Epoch 275 Batch 300 Loss 0.0460 Accuracy 0.4689
# Epoch 275, Loss: 0.04606578126549721, Test Loss: 0.06501125544309616, Test R^2: 0.5868372917175293
# Saving checkpoint for epoch 275 at ./checkpoints_64_21_pos/train/ckpt-55
# Epoch 275 Loss 0.0461 Accuracy 0.4689
# Time taken for 1 epoch: 46.36 secs
#
# Epoch 276 Batch 0 Loss 0.0274 Accuracy 0.4689
# Epoch 276 Batch 300 Loss 0.0464 Accuracy 0.4700
# Epoch 276, Loss: 0.046411700546741486, Test Loss: 0.06499707698822021, Test R^2: 0.5870784521102905
# Epoch 277 Batch 0 Loss 0.0490 Accuracy 0.4700
# Epoch 277 Batch 300 Loss 0.0461 Accuracy 0.4710
# Epoch 277, Loss: 0.04621724411845207, Test Loss: 0.06498370319604874, Test R^2: 0.5873087644577026
# Epoch 278 Batch 0 Loss 0.0398 Accuracy 0.4710
# Epoch 278 Batch 300 Loss 0.0462 Accuracy 0.4720
# Epoch 278, Loss: 0.04608966410160065, Test Loss: 0.06496869027614594, Test R^2: 0.5875409841537476
# Epoch 279 Batch 0 Loss 0.0279 Accuracy 0.4720
# Epoch 279 Batch 300 Loss 0.0462 Accuracy 0.4730
# Epoch 279, Loss: 0.04625651240348816, Test Loss: 0.06495896726846695, Test R^2: 0.5877346992492676
# Epoch 280 Batch 0 Loss 0.0524 Accuracy 0.4730
# Epoch 280 Batch 300 Loss 0.0463 Accuracy 0.4740
# Epoch 280, Loss: 0.046106256544589996, Test Loss: 0.06494782865047455, Test R^2: 0.5879471302032471
# Saving checkpoint for epoch 280 at ./checkpoints_64_21_pos/train/ckpt-56
# Epoch 280 Loss 0.0461 Accuracy 0.4740
# Time taken for 1 epoch: 47.74 secs
#
# Epoch 281 Batch 0 Loss 0.0359 Accuracy 0.4740
# Epoch 281 Batch 300 Loss 0.0458 Accuracy 0.4750
# Epoch 281, Loss: 0.04596926271915436, Test Loss: 0.06493470817804337, Test R^2: 0.5881747007369995
# Epoch 282 Batch 0 Loss 0.0541 Accuracy 0.4751
# Epoch 282 Batch 300 Loss 0.0463 Accuracy 0.4760
# Epoch 282, Loss: 0.04623662680387497, Test Loss: 0.06492139399051666, Test R^2: 0.5883988738059998
# Epoch 283 Batch 0 Loss 0.0566 Accuracy 0.4761
# Epoch 283 Batch 300 Loss 0.0462 Accuracy 0.4770
# Epoch 283, Loss: 0.04626394808292389, Test Loss: 0.06490820646286011, Test R^2: 0.5886191129684448
# Epoch 284 Batch 0 Loss 0.0442 Accuracy 0.4770
# Epoch 284 Batch 300 Loss 0.0459 Accuracy 0.4780
# Epoch 284, Loss: 0.04590229317545891, Test Loss: 0.06489463895559311, Test R^2: 0.5888405442237854
# Epoch 285 Batch 0 Loss 0.0602 Accuracy 0.4780
# Epoch 285 Batch 300 Loss 0.0459 Accuracy 0.4790
# Epoch 285, Loss: 0.04599284753203392, Test Loss: 0.06488294899463654, Test R^2: 0.5890491008758545
# Saving checkpoint for epoch 285 at ./checkpoints_64_21_pos/train/ckpt-57
# Epoch 285 Loss 0.0460 Accuracy 0.4790
# Time taken for 1 epoch: 46.34 secs
#
# Epoch 286 Batch 0 Loss 0.0332 Accuracy 0.4790
# Epoch 286 Batch 300 Loss 0.0460 Accuracy 0.4800
# Epoch 286, Loss: 0.045960184186697006, Test Loss: 0.06487222760915756, Test R^2: 0.5892429351806641
# Epoch 287 Batch 0 Loss 0.0456 Accuracy 0.4800
# Epoch 287 Batch 300 Loss 0.0461 Accuracy 0.4809
# Epoch 287, Loss: 0.04612253978848457, Test Loss: 0.06485994905233383, Test R^2: 0.5894628763198853
# Epoch 288 Batch 0 Loss 0.0409 Accuracy 0.4809
# Epoch 288 Batch 300 Loss 0.0458 Accuracy 0.4819
# Epoch 288, Loss: 0.04577945917844772, Test Loss: 0.06484772264957428, Test R^2: 0.5896586179733276
# Epoch 289 Batch 0 Loss 0.0542 Accuracy 0.4819
# Epoch 289 Batch 300 Loss 0.0462 Accuracy 0.4828
# Epoch 289, Loss: 0.0461859405040741, Test Loss: 0.06483682245016098, Test R^2: 0.5898623466491699
# Epoch 290 Batch 0 Loss 0.0437 Accuracy 0.4828
# Epoch 290 Batch 300 Loss 0.0461 Accuracy 0.4838
# Epoch 290, Loss: 0.04599573090672493, Test Loss: 0.06482303887605667, Test R^2: 0.5900781750679016
# Saving checkpoint for epoch 290 at ./checkpoints_64_21_pos/train/ckpt-58
# Epoch 290 Loss 0.0460 Accuracy 0.4838
# Time taken for 1 epoch: 47.62 secs
#
# Epoch 291 Batch 0 Loss 0.0492 Accuracy 0.4838
# Epoch 291 Batch 300 Loss 0.0459 Accuracy 0.4847
# Epoch 291, Loss: 0.04592897742986679, Test Loss: 0.06481025367975235, Test R^2: 0.5902916193008423
# Epoch 292 Batch 0 Loss 0.0435 Accuracy 0.4847
# Epoch 292 Batch 300 Loss 0.0459 Accuracy 0.4856
# Epoch 292, Loss: 0.04603521153330803, Test Loss: 0.0647970512509346, Test R^2: 0.5905092358589172
# Epoch 293 Batch 0 Loss 0.0593 Accuracy 0.4857
# Epoch 293 Batch 300 Loss 0.0460 Accuracy 0.4866
# Epoch 293, Loss: 0.046087536960840225, Test Loss: 0.06478368490934372, Test R^2: 0.5907272100448608
# Epoch 294 Batch 0 Loss 0.0317 Accuracy 0.4866
# Epoch 294 Batch 300 Loss 0.0457 Accuracy 0.4875
# Epoch 294, Loss: 0.04589508846402168, Test Loss: 0.06477225571870804, Test R^2: 0.5909315943717957
# Epoch 295 Batch 0 Loss 0.0308 Accuracy 0.4875
# Epoch 295 Batch 300 Loss 0.0460 Accuracy 0.4884
# Epoch 295, Loss: 0.04609308019280434, Test Loss: 0.06476102024316788, Test R^2: 0.5911312699317932
# Saving checkpoint for epoch 295 at ./checkpoints_64_21_pos/train/ckpt-59
# Epoch 295 Loss 0.0461 Accuracy 0.4884
# Time taken for 1 epoch: 47.49 secs
#
# Epoch 296 Batch 0 Loss 0.0447 Accuracy 0.4884
# Epoch 296 Batch 300 Loss 0.0460 Accuracy 0.4893
# Epoch 296, Loss: 0.046106040477752686, Test Loss: 0.06474965065717697, Test R^2: 0.5913240909576416
# Epoch 297 Batch 0 Loss 0.0281 Accuracy 0.4893
# Epoch 297 Batch 300 Loss 0.0458 Accuracy 0.4902
# Epoch 297, Loss: 0.0457487478852272, Test Loss: 0.06473769247531891, Test R^2: 0.591528058052063
# Epoch 298 Batch 0 Loss 0.0459 Accuracy 0.4902
# Epoch 298 Batch 300 Loss 0.0457 Accuracy 0.4911
# Epoch 298, Loss: 0.045658010989427567, Test Loss: 0.06472595036029816, Test R^2: 0.5917215347290039
# Epoch 299 Batch 0 Loss 0.0488 Accuracy 0.4911
# Epoch 299 Batch 300 Loss 0.0458 Accuracy 0.4920
# Epoch 299, Loss: 0.04576342925429344, Test Loss: 0.06471453607082367, Test R^2: 0.5919135808944702
# Epoch 300 Batch 0 Loss 0.0576 Accuracy 0.4920
# Epoch 300 Batch 300 Loss 0.0457 Accuracy 0.4929
# Epoch 300, Loss: 0.04579616338014603, Test Loss: 0.06470271199941635, Test R^2: 0.5921059846878052
# Saving checkpoint for epoch 300 at ./checkpoints_64_21_pos/train/ckpt-60
# Epoch 300 Loss 0.0458 Accuracy 0.4929
# Time taken for 1 epoch: 48.41 secs

# %% [markdown]
# ## Visualize attentions

# %%
df["seq_spaced"] = seq_spaced
def visualize_attention(heads, labels, attention):
    plt.rcParams["figure.figsize"] = (20,5)
    fig, axs = plt.subplots(1,heads)
    plt.set_cmap('bwr')
    for i in range(heads):
        ax = axs[i]
        cax = ax.matshow(attention[i])
        ax.set_xticks(range(len(labels)))
        ax.set_yticks(range(len(labels)))
        #labels = [label for label in R.to_numpy()[0]]
        ax.set_xticklabels(labels, rotation=90)
        #labels = [label for label in R.to_numpy()[0]]
        ax.set_yticklabels(labels)
        print(f"head{i}: {tf.reduce_max(attention[i])}")
        print(f"head{i}: {tf.reduce_min(attention[i])}")
    cbar = fig.colorbar(cax)

def plot_attention_head(sequence, attention, heads):
    # The plot is of the attention when a token was generated.
    # # The model didn't generate `<START>` in the output. Skip it.
    labels = [label for label in sequence.to_numpy()[0]]
    #translated_tokens = translated_tokens[1:]
    #ax = plt.gca()
    visualize_attention(heads = heads, labels=labels, attention=attention)
# Out:
# /var/folders/x_/gdpx2y_53xb045v6zhcn7rrr0000gn/T/ipykernel_82828/1990594541.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["seq_spaced"] = seq_spaced

# %% [markdown]
# ## Test individual sequence

# %%
seq = 'UAGUAGU'
sequence_demo = df[df.sevenMer == seq].seq_spaced
rka_for_show = df[df.sevenMer == seq].RKA_logplus1
p = vectorize_layer(sequence_demo)
result = model(p)
att = model.layers[1].get_attention()['attentions_1'][0]
matmul_qk_s = model.layers[1].get_matmul_qks()['matmul_qk_1'][0]
R = sequence_demo.str.split(" ")

plot_attention_head(R,matmul_qk_s, num_heads)
print('sequence: ', sequence_demo.to_numpy())
print(f'predicted RKA: {result.numpy()}, real RKA {rka_for_show}')
# Out:
# head0: 10.08450698852539
# head0: -17.92645263671875
# head1: 6.653016567230225
# head1: -9.913814544677734
# head2: 10.091736793518066
# head2: -8.309465408325195
# sequence:  ['U A G U A G U']
# predicted RKA: 0.63470059633255, real RKA 13003    0.782336
# Name: RKA_logplus1, dtype: float64

# %%
seq = 'UAGUAGU'
sequence_demo = df[df.sevenMer == seq].seq_spaced
rka_for_show = df[df.sevenMer == seq].RKA_logplus1
p = vectorize_layer(sequence_demo)
result = model(p)
att = model.layers[1].get_attention()['attentions_1'][0]
R = sequence_demo.str.split(" ")

plot_attention_head(R,att, num_heads)
print('sequence: ', sequence_demo.to_numpy())
print(f'predicted RKA: {result.numpy()}, real RKA {rka_for_show}')
# Out:
# head0: 0.8808605074882507
# head0: 2.2231404727790505e-05
# head1: 0.8084603548049927
# head1: 0.0011402004165574908
# head2: 0.9505181908607483
# head2: 0.0026911089662462473
# sequence:  ['U A G U A G U']
# predicted RKA: 0.63470059633255, real RKA 13003    0.782336
# Name: RKA_logplus1, dtype: float64

# %% [markdown]
# ## Verify the predicted result

# %%
result = model.predict(all_vec_seq.batch(100))
result.shape
# Out:
# (15454,)

# %%
plt.rcParams["figure.figsize"] = (6,5)
sns.scatterplot(np.log(1+df.RKA), np.log(np.exp(result)))
# Out:
# /Users/fatmimi/.pyenv/versions/3.8.7/envs/mactf-sandbox/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='RKA'>

# %%
# Calculate R^2
from sklearn.metrics import r2_score
r2_score(np.log(1+df.RKA), result)
# Out:
# 0.6460414733738298

# %%
sns.histplot(np.log(df.RKA), color = "orange")
sns.histplot(np.log(np.exp(result)-1))
# Out:
# <AxesSubplot:xlabel='RKA', ylabel='Count'>
